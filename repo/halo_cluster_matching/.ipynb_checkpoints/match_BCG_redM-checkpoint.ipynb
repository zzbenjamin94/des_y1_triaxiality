# %% [markdown]
# ## Check if BCGs for miscentered clusters are members of the halo matched redM cluster.
#
# **Description**
# Compares the BCGs in the miscentered clusters with the redM member catalog to see fraction of miscentered BCGs that are members of the same cluster. If they do not belong to the same cluster then the BCG is a line of sight projection.
#
# **Dataset**:
# **redM_halos_fullmatchingparams_v1.2_redMv1.6.data**
#
# Latest version of redM-halo matching using v1.6 of Buzzard and v1.2 of halo-matching algo.
#
# MEM_MATCH_ID: The redMaPPer ID identified by v1.2 of my matching scheme.
#
# GALAXY_ID: ID of the BCG Galaxy.
#
# **Buzzard-0_1.6_y3_run_redmapper_v6.4.20_lgt20_vl02_catalog_members.fit**
#
# Contains member galaxies of the redMaPPer catalog.

# %%
import numpy as np
import sys
sys.path.append('/home/zzbenjamin94/Desktop/Astronomy/Research/DES_Galaxy_Cluster')

# import pyplot and set some parameters to make plots prettier
import matplotlib.pyplot as plt
from tools.plot_utils import plot_pretty
import pickle
plot_pretty()

# setup notebook for inline figures
# %matplotlib inline

from tools.setup.setup import data_home_dir, home_dir, bigdata_home_dir
import astropy.io.fits as fits

datadir = data_home_dir()
homedir = home_dir()
bigdatadir = bigdata_home_dir()

# %% [markdown]
# ## Import the redM matched BCG/halo catalog

# %%
#Miscentering cut
import pickle

redM_halos = homedir + 'output/buzzard/redM_halos_fullmatchingparams_matchingv1.3_Buzzardv1.6.data'

infile = open(redM_halos,'rb')
redM_halos = pickle.load(infile)
infile.close()

redM_halos = redM_halos.view(np.recarray)
print redM_halos.dtype
print len(redM_halos)
# Out:
# (numpy.record, [('GALAXY_ID', '<i8'), ('HALOID', '<i8'), ('DESCID', '>i8'), ('RA_OBS', '>f8'), ('DEC_OBS', '>f8'), ('TRA', '>f8'), ('TDEC', '>f8'), ('Z', '>f8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8'), ('matching_ID', '<i8'), ('MEM_MATCH_ID', '<i8'), ('LAMBDA_CHISQ', '<f8'), ('RA_REDM', '<f8'), ('DEC_REDM', '<f8'), ('q', '<f8'), ('s', '<f8'), ('cosi', '<f8'), ('centered_flag', '<i8')])
# 13628

# %% [markdown]
# ## Import redM member catalog

# %%
redM_dir = bigdatadir + 'Buzzard_Sims/v1.6/buzzard_halo/redM/buzzard-0_1.6_y3_run_redmapper_v6.4.20_lgt5_vl02_catalog_members.fit'
redM_list = fits.open(redM_dir)
redM_members = redM_list[1].data

#Checking FITS into
#hrun_list.info()
print "Names of columns in redM_data are: \n"
print redM_members.names

#Converting FITS files into record array
redM_members = np.array(redM_data, dtype=redM_data.dtype)
redM_members = redM_data.view(np.recarray)

print "\n Number of halos is", len(redM_members.ID)
# Out:
# Names of columns in redM_data are:
#
# ['MEM_MATCH_ID', 'Z', 'RA', 'DEC', 'R', 'P', 'PFREE', 'THETA_I', 'THETA_R', 'MODEL_MAG', 'MODEL_MAGERR', 'REFMAG_FIT', 'REFMAG_FIT_E', 'REFMAG', 'REFMAG_ERR', 'ZRED', 'ZRED_E', 'ZRED2', 'ZRED2_E', 'CHISQ', 'EBV', 'ZSPEC', 'ID']
#
#  Number of halos is 6418974

# %% [markdown]
# ## Sorting and validating
# * for each BCG sort by centered and miscentered.
# * For miscentered, find MEM_MATCH_ID, and find galaxies with same MEM_MATCH_ID in redM_member catalog
# * See if in that redM_member subset there is one with matching GALAXY_ID (or ID in redM_member catalog).
# * Create data vectors with statistical informtion -- distribution as fraction, mass, redshift, lamdba.

# %% [markdown]
# ### Sort by miscentered and centered

# %%
#For miscentered
dummy = np.where(redM_halos.centered_flag == 0)
BCG_miscent = redM_halos[dummy]
print "Number of miscentered BCGs are ", len(BCG_miscent)

#Centered
dummy = np.where(redM_halos.centered_flag == 1)
BCG_cent = redM_halos[dummy]
print "Number of centered BCGs are ", len(BCG_cent)
# Out:
# Number of miscentered BCGs are  5087
# Number of centered BCGs are  8541

# %% [markdown]
# ### For each miscentered BCG, find redM_members with same MEM_MATCH_ID and GALAXY_ID

# %% [markdown]
# #### Testing

# %%
test_ind = 100
halos_test = redM_halos[test_ind]
dummy1 = halos_test.MEM_MATCH_ID
print "centered flag: ", halos_test.centered_flag 
print "Galaxy ID: ", halos_test.GALAXY_ID
dummy2 = np.where(redM_members.MEM_MATCH_ID == dummy1)
matched_gal = redM_members[dummy2]
print "Number of galaxies with same redM ID: ", len(dummy2[0])
#print "Number of galaxies identified by the halo: ", halos_test.NGALS
dummy3 = np.where(redM_members.ID == halos_test.GALAXY_ID)
print "Gal indices with same ID as BCG:", dummy3
print matched_gal[0].RA, matched_gal[0].DEC, matched_gal[0].Z, sum(matched_gal.P)
print halos_test.RA_OBS, halos_test.DEC_OBS, halos_test.Z, halos_test.LAMBDA_CHISQ
# Out:
# centered flag:  1
# Galaxy ID:  111003823105
# Number of galaxies with same redM ID:  240
# Gal indices with same ID as BCG: (array([], dtype=int64),)
# 7.95707231346402 -52.79211237687289 0.6178452 148.00561816617846
# 7.964012932364474 -52.85326228879729 0.6126871109008789 130.0833740234375

# %% [markdown]
# #### Run for all

# %%
num_BCG_found = 0
for i, cur_BCG in enumerate(BCG_miscent):
    BCG_redM_ID = cur_BCG.MEM_MATCH_ID
    BCG_gal_ID = cur_BCG.GALAXY_ID
    
    #Find redM members with matching MEM_MATCH_ID
    MEM_MATCH_ID_ind = np.where(redM_members.MEM_MATCH_ID == BCG_redM_ID)
    redM_matched = redM_members[MEM_MATCH_ID_ind]
    
    #Within members identified by same redMaPPer cluster, see if miscent BCG corresponds to any one of them. 
    gal_match_ind = np.where(redM_matched.ID == cur_BCG.GALAXY_ID)[0]
    num_BCG_found += len(gal_match_ind)
    
    if i%100 == 0:
        print "Out of {:d} miscentered BCGs, {:d} found in same redMaPPer cluster.".format(i+1, num_BCG_found)
    
print "Out of {:d} miscentered BCGs, {:d} found in same redMaPPer cluster.".format(len(BCG_miscent), num_BCG_found)
# Out:
# Out of 1 miscentered BCGs, 0 found in same redMaPPer cluster.
# Out of 101 miscentered BCGs, 0 found in same redMaPPer cluster.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-8e2ac6619b02> in <module>()
#       5
#       6     #Find redM members with matching MEM_MATCH_ID
# ----> 7     MEM_MATCH_ID_ind = np.where(redM_members.MEM_MATCH_ID == BCG_redM_ID)
#       8     redM_matched = redM_members[MEM_MATCH_ID_ind]
#       9
#
# KeyboardInterrupt:

# %% [markdown]
# ### For each each miscentered BCG, find members with matching MEM_MATCH_ID and coordinates

# %% [markdown]
# #### Testing

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.cosmology import WMAP9 as cosmo
from astropy.coordinates import SkyCoord

## For each matched halo in fullmatchingparams replace the GALAXY_ID with ID from BCG_data
## Finding BCG's nearest halo neighbor.

#Find the centered ones
ang_lim = 1e-5
z_lim = 0.001
BCG_coord = SkyCoord(redM_halos.RA_OBS*u.deg, redM_halos.DEC_OBS*u.deg,  frame='icrs')
redM_mem_coord = SkyCoord(matched_gal.RA*u.deg, matched_gal.DEC*u.deg, frame='icrs')

def find_nearest(ind):
    dist_sep = redM_mem_coord.separation(BCG_coord[ind])
    idx = (np.abs(dist_sep)).argmin()
    return idx, dist_sep[idx].value

#Testing match of specific halo using index testn
testarr = np.arange(0,13000,100)
for i, testn in enumerate(testarr):
    halos_test = redM_halos[testn]
    dummy1 = halos_test.MEM_MATCH_ID
    dummy2 = np.where(redM_members.MEM_MATCH_ID == dummy1)
    matched_gal = redM_members[dummy2]
    redM_mem_coord = SkyCoord(matched_gal.RA*u.deg, matched_gal.DEC*u.deg, frame='icrs')

    ind, dist = find_nearest(testn)
    print "BCG index: ", testn
    print "Halo matched index:", ind
    print "Total angular separation: ", dist
    print "RA difference: ", halos_test.RA_OBS -  matched_gal[ind].RA
    print "DEC difference: ", halos_test.DEC_OBS -  matched_gal[ind].DEC
    print "IDs are ", halos_test.GALAXY_ID, matched_gal[ind].ID
    #print hrun_data.Z[testn] - redM_gal_data.Z[ind] #Some error in redshift
    print "Redshift difference: {:2g} \n".format(halos_test.Z -  matched_gal[ind].Z) #Small error in redshift
# Out:
# BCG index:  0
# Halo matched index: 232
# Total angular separation:  1.7860511156e-06
# RA difference:  6.93747722380067e-07
# DEC difference:  1.7075106342190338e-06
# IDs are  90002853535 90002140438
# Redshift difference: -0.00224614
#
# BCG index:  100
# Halo matched index: 23
# Total angular separation:  9.7446804693e-07
# RA difference:  1.1282925918010278e-06
# DEC difference:  -6.966913375094919e-07
# IDs are  111003823105 111002972414
# Redshift difference: -0.00515807
#
# BCG index:  200
# Halo matched index: 43
# Total angular separation:  4.5471131529e-06
# RA difference:  7.1822129825704906e-06
# DEC difference:  -2.7177510233400426e-06
# IDs are  115002017265 115002342352
# Redshift difference: 0.000693768
#
# BCG index:  300
# Halo matched index: 30
# Total angular separation:  2.148906428e-06
# RA difference:  -1.3667708316233984e-06
# DEC difference:  1.8812419710911854e-06
# IDs are  105002597225 105002589538
# Redshift difference: -0.00958788
#
# BCG index:  400
# Halo matched index: 13
# Total angular separation:  2.06125305791e-06
# RA difference:  -3.248762709517905e-06
# DEC difference:  -3.497274292385555e-07
# IDs are  120002219198 120004204628
# Redshift difference: -0.00394195
#
# BCG index:  500
# Halo matched index: 38
# Total angular separation:  1.61741294556e-06
# RA difference:  -5.7995862334792037e-08
# DEC difference:  1.6169693353162984e-06
# IDs are  50002044784 50003594666
# Redshift difference: -0.00292149
#
# BCG index:  600
# Halo matched index: 51
# Total angular separation:  1.61577893006e-06
# RA difference:  1.6173534973518144e-06
# DEC difference:  -6.877128777560415e-08
# IDs are  368002393797 368004381590
# Redshift difference: 0.000365198
#
# BCG index:  700
# Halo matched index: 4
# Total angular separation:  2.00268857563e-06
# RA difference:  2.163181228809208e-06
# DEC difference:  1.5643004473986366e-06
# IDs are  52003033459 52003642942
# Redshift difference: 0.00874537
#
# BCG index:  800
# Halo matched index: 66
# Total angular separation:  2.8547124428e-07
# RA difference:  -3.1238523945376073e-07
# DEC difference:  8.660660810733134e-08
# IDs are  33000899877 33001658070
# Redshift difference: -0.00257629
#
# BCG index:  900
# Halo matched index: 23
# Total angular separation:  3.69581286401e-06
# RA difference:  -6.256171047880343e-06
# DEC difference:  2.330189325050469e-06
# IDs are  121001678701 121004110069
# Redshift difference: -0.00623882
#
# BCG index:  1000
# Halo matched index: 39
# Total angular separation:  2.04173850609e-06
# RA difference:  2.096266335627206e-06
# DEC difference:  6.864862633904067e-07
# IDs are  382001108438 382002108891
# Redshift difference: 0.000215858
#
# BCG index:  1100
# Halo matched index: 4
# Total angular separation:  3.65593749741e-06
# RA difference:  -3.1414464842782763e-06
# DEC difference:  -3.316434558087167e-06
# IDs are  118002215782 118002427010
# Redshift difference: 0.00390577
#
# BCG index:  1200
# Halo matched index: 19
# Total angular separation:  2.67355116069e-06
# RA difference:  2.6421436700729828e-06
# DEC difference:  -1.7578403941342913e-06
# IDs are  103001722170 103004161666
# Redshift difference: 0.00343925
#
# BCG index:  1300
# Halo matched index: 45
# Total angular separation:  1.87562113129e-06
# RA difference:  -4.5953447624924593e-07
# DEC difference:  1.8495122731110314e-06
# IDs are  114002910916 114003887055
# Redshift difference: -0.00840425
#
# BCG index:  1400
# Halo matched index: 6
# Total angular separation:  1.26846384535e-06
# RA difference:  1.6699806195674682e-06
# DEC difference:  -7.141277365008136e-07
# IDs are  111002237461 111004126249
# Redshift difference: -0.00169617
#
# BCG index:  1500
# Halo matched index: 22
# Total angular separation:  3.65973978713e-06
# RA difference:  3.6685530915292475e-06
# DEC difference:  6.658613660448509e-08
# IDs are  364001339631 364003506700
# Redshift difference: -0.00132561
#
# IDs are  47001388130 47002389435
# Redshift difference: 0.00549787
#
# BCG index:  5800
# Halo matched index: 3
# Total angular separation:  5.68732258701e-07
# RA difference:  6.000253307547609e-07
# DEC difference:  9.739528294971933e-08
# IDs are  32003091289 32004833494
# Redshift difference: 0.000967443
#
# BCG index:  5900
# Halo matched index: 18
# Total angular separation:  1.66582178312e-06
# RA difference:  1.5408690572371597e-06
# DEC difference:  1.0009422908296983e-06
# IDs are  15000941690 15000000009
# Redshift difference: 0.00435242
#
# BCG index:  6000
# Halo matched index: 8
# Total angular separation:  2.18222045464e-06
# RA difference:  1.0699768893118744e-07
# DEC difference:  -2.181781283638884e-06
# IDs are  60002938310 60001998125
# Redshift difference: -0.00953239
#
# BCG index:  6100
# Halo matched index: 14
# Total angular separation:  6.89830746045e-07
# RA difference:  6.833259931227076e-07
# DEC difference:  -9.4513724971379e-08
# IDs are  64002885076 64002050941
# Redshift difference: -0.00865841
#
# BCG index:  6200
# Halo matched index: 19
# Total angular separation:  2.55374073729e-06
# RA difference:  -2.511108303515641e-06
# DEC difference:  1.4735454030301298e-06
# IDs are  105002899040 105004152204
# Redshift difference: -0.00225568
#
# BCG index:  6300
# Halo matched index: 8
# Total angular separation:  3.57618800716e-06
# RA difference:  3.5650944205656288e-06
# DEC difference:  2.8494846604498747e-07
# IDs are  350001289650 350004199161
# Redshift difference: -0.00939882
#
# BCG index:  6400
# Halo matched index: 21
# Total angular separation:  2.45483173439e-06
# RA difference:  -3.517967343213968e-06
# DEC difference:  -1.0727973105417732e-06
# IDs are  87001172699 87001833559
# Redshift difference: 0.00455853
#
# BCG index:  6500
# Halo matched index: 20
# Total angular separation:  7.9063213024e-07
# RA difference:  3.6918540047281567e-07
# DEC difference:  -7.605155900591853e-07
# IDs are  52000671575 52000324104
# Redshift difference: -0.00681451
#
# BCG index:  6600
# Halo matched index: 8
# Total angular separation:  1.63387618015e-06
# RA difference:  -1.4937092700506582e-06
# DEC difference:  -1.0747507062092154e-06
# IDs are  22001747645 22004151907
# Redshift difference: -0.00719646
#
# BCG index:  6700
# Halo matched index: 6
# Total angular separation:  2.58594789834e-06
# RA difference:  2.583248043919184e-06
# DEC difference:  -1.255683830247989e-07
# IDs are  368001309077 368004683079
# Redshift difference: 0.00687549
#
# BCG index:  6800
# Halo matched index: 17
# Total angular separation:  3.18866579611e-06
# RA difference:  -3.183707066867214e-06
# DEC difference:  3.2943148031705505e-07
# IDs are  372002636857 372002294983
# Redshift difference: 0.00715834
#
# BCG index:  6900
# Halo matched index: 9
# Total angular separation:  7.15048236139e-06
# RA difference:  7.1265984047386155e-06
# DEC difference:  5.878871113251805e-07
# IDs are  64001160474 64003861975
# Redshift difference: 0.00235802
#
# BCG index:  7000
# Halo matched index: 16
# Total angular separation:  1.74544524317e-07
# RA difference:  -1.463177952132355e-07
# DEC difference:  -9.526895738964924e-08
# IDs are  364002689647 364003185903
# Redshift difference: -0.0051381
#
# BCG index:  7100
# Halo matched index: 25
# Total angular separation:  6.85098220336e-07
# RA difference:  -1.1152273486914055e-06
# DEC difference:  -2.5285721960699448e-08
# DEC difference:  -1.8153294618628024e-06
# IDs are  28003404953 28003620885
# Redshift difference: -0.00584
#
# BCG index:  8600
# Halo matched index: 21
# Total angular separation:  9.59256108423e-07
# RA difference:  1.0081439540954307e-06
# DEC difference:  6.704046029426536e-08
# IDs are  9002288933 9004039385
# Redshift difference: -0.00282371
#
# BCG index:  8700
# Halo matched index: 14
# Total angular separation:  1.42671702853e-06
# RA difference:  1.4999752409039502e-06
# DEC difference:  -2.3416039596213523e-07
# IDs are  7001340728 7004334820
# Redshift difference: -0.00410542
#
# BCG index:  8800
# Halo matched index: 59
# Total angular separation:  0.00226022328066
# RA difference:  -0.001516764436544804
# DEC difference:  0.0017010588452475162
# IDs are  376001982668 376002469679
# Redshift difference: -0.00045979
#
# BCG index:  8900
# Halo matched index: 44
# Total angular separation:  1.66153489388e-06
# RA difference:  -4.942102904692547e-07
# DEC difference:  -1.6064291692430288e-06
# IDs are  20000174778 20000668796
# Redshift difference: -0.0013137
#
# BCG index:  9000
# Halo matched index: 46
# Total angular separation:  3.77791573477e-06
# RA difference:  -3.787502695473677e-06
# DEC difference:  2.8988403677487895e-08
# IDs are  357000784625 357001605615
# Redshift difference: -0.00381479
#
# BCG index:  9100
# Halo matched index: 41
# Total angular separation:  1.7742651674e-06
# RA difference:  -3.0162006332545843e-06
# DEC difference:  1.5873808933974942e-07
# IDs are  111002234813 111004122909
# Redshift difference: 0.000380993
#
# BCG index:  9200
# Halo matched index: 20
# Total angular separation:  1.50525580647e-06
# RA difference:  -1.5079033985898604e-06
# DEC difference:  5.1391276123524676e-08
# IDs are  364002688236 364003183912
# Redshift difference: 0.00280792
#
# BCG index:  9300
# Halo matched index: 30
# Total angular separation:  2.90539272312e-07
# RA difference:  5.330036856321385e-09
# DEC difference:  -2.9049039818040967e-07
# IDs are  66002029451 66001618627
# Redshift difference: -0.00624901
#
# BCG index:  9400
# Halo matched index: 7
# Total angular separation:  0.00193313418767
# RA difference:  0.00011227518780287937
# DEC difference:  0.0019298715829298985
# IDs are  425001204725 425001232203
# Redshift difference: -0.0061959
#
# BCG index:  9500
# Halo matched index: 33
# Total angular separation:  2.23753502488e-06
# RA difference:  -1.7306617223766807e-06
# DEC difference:  -1.8128955687757298e-06
# IDs are  112003918304 112001974786
# Redshift difference: -0.00504982
#
# BCG index:  9600
# Halo matched index: 19
# Total angular separation:  2.28577953218e-06
# RA difference:  -2.8410540835466236e-06
# DEC difference:  1.3556703777339862e-06
# IDs are  94002814507 94004048849
# Redshift difference: -0.0094009
#
# BCG index:  9700
# Halo matched index: 0
# Total angular separation:  0.00124690191412
# RA difference:  -0.0015027553672126714
# DEC difference:  -0.0007682038077092557
# IDs are  30002181412 30001582965
# Redshift difference: 0.000398636
#
# BCG index:  9800
# Halo matched index: 14
# Total angular separation:  1.76364200573e-06
# RA difference:  -1.8620042148143057e-06
# DEC difference:  -5.618460292566851e-07
# IDs are  382000000494 382001305126
# Redshift difference: 0.0025508
#
# BCG index:  9900
# Halo matched index: 10
# Total angular separation:  0.00169162482591
# RA difference:  -0.002200576605289939
# DEC difference:  -0.0008608618511303234
# IDs are  44002130911 44003516567
# Redshift difference: 0.00604656
#
# BCG index:  10000
# Halo matched index: 38
# Total angular separation:  9.29466895771e-07
# RA difference:  -7.508207389150812e-07
# DEC difference:  8.209120068158882e-07
# IDs are  51003335321 51004749172
# Redshift difference: -0.0056988
#
# BCG index:  10100
# Halo matched index: 1
# Total angular separation:  1.966520005e-06
# RA difference:  2.0083338299059506e-06
# DEC difference:  -1.5850547185891628e-06
# IDs are  31001609358 31002762052
# Redshift difference: 0.00484267
#
# BCG index:  10200
# Halo matched index: 31
# Total angular separation:  1.02951448783e-06
# RA difference:  6.07760568982485e-07
# DEC difference:  9.816557664521497e-07
# IDs are  116001151379 116002151144
# Redshift difference: -0.00295353
#
# BCG index:  10300
# Halo matched index: 31
# Total angular separation:  0.0021799904323
# RA difference:  -0.0002100188770768341
# DEC difference:  -0.0021748738763136544
# IDs are  48001809934 48003460113
# Redshift difference: -0.00642288
#
# BCG index:  10400
# Halo matched index: 19
# Total angular separation:  1.60265061208e-06
# RA difference:  1.807262989927949e-06
# DEC difference:  1.1199823148899668e-06
# IDs are  50001089091 50002460681
# Redshift difference: -0.00950524
#
# BCG index:  10500
# Halo matched index: 26
# Total angular separation:  0.000217371290983
# RA difference:  -9.719521167994571e-05
# DEC difference:  -0.0002136336754574586
# IDs are  55001187897 55002165001
# Redshift difference: 0.000780314
#
# BCG index:  10600
# Halo matched index: 2
# Total angular separation:  1.69732971879e-06
# RA difference:  -1.6885337288385927e-06
# DEC difference:  -6.779312577975816e-07
# IDs are  381003085699 381004043082
# Redshift difference: 0.000517011
#
# BCG index:  10700
# Halo matched index: 25
# Total angular separation:  0.00429949535747
# RA difference:  -0.005194612605407656
# DEC difference:  -0.0036797936134007614
# IDs are  117002796038 117003308201
# Redshift difference: -0.00336605
#
# BCG index:  10800
# Halo matched index: 2
# Total angular separation:  0.00476198782836
# RA difference:  -0.009494407907538971
# DEC difference:  0.0017570206556598578
# IDs are  116002156827 116001817973
# Redshift difference: -0.00972307
#
# BCG index:  10900
# Halo matched index: 2
# Total angular separation:  7.15530627887e-07
# RA difference:  5.371623501559952e-08
# DEC difference:  7.143424483047056e-07
# IDs are  39002060070 39002811791
# Redshift difference: 0.00199953
#
# BCG index:  11000
# Halo matched index: 20
# Total angular separation:  3.35997925454e-06
# RA difference:  3.409323994674196e-06
# DEC difference:  2.9166699206939484e-06
# IDs are  118000364415 118000645174
# Redshift difference: -0.00270675
#
# BCG index:  11100
# Halo matched index: 26
# Total angular separation:  7.14540522034e-07
# RA difference:  -6.037960389448926e-07
# DEC difference:  5.019167872433172e-07
# IDs are  36002337338 36003599878
# Redshift difference: 0.00446016
#
# BCG index:  11200
# Halo matched index: 7
# Total angular separation:  3.41751828935e-07
# RA difference:  2.3256342629451865e-07
# DEC difference:  -2.583284270940567e-07
# IDs are  377002891347 377003920469
# Redshift difference: -0.00165761
#
# BCG index:  11300
# Halo matched index: 38
# Total angular separation:  0.0104735618426
# RA difference:  -0.007512953319668725
# DEC difference:  -0.007600672245150264
# IDs are  16000000312 16000946570
# Redshift difference: -0.00552912
#
# BCG index:  11400
# Halo matched index: 1
# Total angular separation:  0.00222676424209
# RA difference:  -0.002043205794556968
# DEC difference:  -0.0011174792888404284
# IDs are  7001957367 7002345842
# Redshift difference: -0.00568175
#
# BCG index:  11500
# Halo matched index: 10
# Total angular separation:  4.11617412219e-06
# RA difference:  -7.128495667529933e-06
# DEC difference:  3.3492520401523507e-07
# IDs are  94002480292 94002214702
# Redshift difference: 0.00547427
#
# BCG index:  11600
# Halo matched index: 22
# Total angular separation:  1.8613023608e-06
# RA difference:  -1.9855037294291833e-06
# DEC difference:  -8.196416558803321e-07
# IDs are  106002595486 106002708889
# Redshift difference: 0.00424916
#
# BCG index:  11700
# Halo matched index: 20
# Total angular separation:  0.00252971695548
# RA difference:  0.00392853480983435
# DEC difference:  0.0008350371638954357
# IDs are  109001340099 109004627457
# Redshift difference: 0.000484198
#
# BCG index:  11800
# Halo matched index: 27
# Total angular separation:  4.17618109309e-07
# RA difference:  -3.1156829294332056e-07
# DEC difference:  2.9580579052890243e-07
# IDs are  12001970789 12001542925
# Redshift difference: 0.00434563
#
# BCG index:  11900
# Halo matched index: 16
# Total angular separation:  0.00531493145925
# RA difference:  0.0015228142138710155
# DEC difference:  -0.005092797239149238
# IDs are  357000474210 357001058320
# Redshift difference: -0.00676912
#
# BCG index:  12000
# Halo matched index: 18
# Total angular separation:  1.53505242386e-06
# RA difference:  1.4816598081779375e-06
# DEC difference:  4.992077027310415e-07
# IDs are  377002197813 377003060304
# Redshift difference: -0.00602317
#
# BCG index:  12100
# Halo matched index: 2
# Total angular separation:  0.000549475033641
# RA difference:  0.0008620741437326274
# DEC difference:  -0.00023505463987305575
# IDs are  52003034375 52003644504
# Redshift difference: 0.00247055
#
# BCG index:  12200
# Halo matched index: 6
# Total angular separation:  2.50576500302e-06
# RA difference:  -2.8213058982373695e-06
# DEC difference:  1.1302832092496828e-06
# IDs are  21002095475 21002765720
# Redshift difference: -0.00820902
#
# BCG index:  12300
# Halo matched index: 2
# Total angular separation:  0.00171408404067
# RA difference:  0.0017401325352182084
# DEC difference:  0.0006441990902494865
# IDs are  33002114571 33001849054
# Redshift difference: -0.000926375
#
# BCG index:  12400
# Halo matched index: 6
# Total angular separation:  2.70843808845e-06
# RA difference:  -3.3087951010202232e-06
# DEC difference:  -1.79726824711679e-06
# IDs are  93004069032 93004934661
# Redshift difference: -0.00941825
#
# BCG index:  12500
# Halo matched index: 15
# Total angular separation:  0.00122160785951
# RA difference:  -0.0011338156010367584
# DEC difference:  0.0004547560720222499
# IDs are  368002063791 368001910248
# Redshift difference: -0.00311297
#
# BCG index:  12600
# Halo matched index: 24
# Total angular separation:  0.00406413942101
# RA difference:  -0.003633367737922555
# DEC difference:  0.0018648321698480075
# IDs are  370001954111 370003964305
# Redshift difference: -0.0042035
#
# BCG index:  12700
# Halo matched index: 26
# Total angular separation:  0.00273644502848
# RA difference:  -0.00048800303557072766
# DEC difference:  -0.002723856011989767
# IDs are  120002923913 120003093932
# Redshift difference: 0.000595629
#
# BCG index:  12800
# Halo matched index: 6
# Total angular separation:  0.00241553548684
# RA difference:  -0.0024242137750478676
# DEC difference:  -0.0017627309402357128
# IDs are  109002390499 109004304001
# Redshift difference: -0.00758749
#
# BCG index:  12900
# Halo matched index: 6
# Total angular separation:  0.00231828260256
# RA difference:  -0.0018557498382776316
# DEC difference:  -0.0016371320110692977
# IDs are  18002828828 18002003362
# Redshift difference: -0.00583452

# %% [markdown]
# #### Real deal

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.cosmology import WMAP9 as cosmo
from astropy.coordinates import SkyCoord

## For each matched halo in fullmatchingparams replace the GALAXY_ID with ID from BCG_data
## Finding BCG's nearest halo neighbor.

#Find the centered ones
ang_lim = 1e-5
z_lim = 0.001
BCG_miscent_coord = SkyCoord(BCG_miscent.RA_OBS*u.deg, BCG_miscent.DEC_OBS*u.deg,  frame='icrs')

def find_nearest(ind):
    dist_sep = redM_mem_coord.separation(BCG_miscent_coord[ind])
    idx = (np.abs(dist_sep)).argmin()
    return idx, dist_sep[idx].value

#Testing match of specific halo using index testn
num_mismatched_redM = 0
mismatched_z_diff= []
mismatched_z = []
for testn in range(len(BCG_miscent)):
    halos_test = BCG_miscent[testn]
    dummy1 = halos_test.MEM_MATCH_ID
    dummy2 = np.where(redM_members.MEM_MATCH_ID == dummy1)
    matched_gal = redM_members[dummy2]
    redM_mem_coord = SkyCoord(matched_gal.RA*u.deg, matched_gal.DEC*u.deg, frame='icrs')
    ind, dist = find_nearest(testn) ##Find nearest galaxy in same redMaPPer cluster

    if dist >1e-4:
        num_mismatched_redM += 1
        mismatched_z_diff.append((halos_test.Z -  matched_gal[ind].Z))
        mismatched_z.append(halos_test.Z)      
        
    if testn%100 == 0:
        print "BCG index: ", testn
        print "Halo matched index:", ind
        print "Total angular separation: ", dist
        print "RA difference: ", halos_test.RA_OBS -  matched_gal[ind].RA
        print "DEC difference: ", halos_test.DEC_OBS -  matched_gal[ind].DEC
        print "IDs are ", halos_test.GALAXY_ID, matched_gal[ind].ID
        #print hrun_data.Z[testn] - redM_gal_data.Z[ind] #Some error in redshift
        print "Redshift difference: {:2g} \n".format(halos_test.Z -  matched_gal[ind].Z) #Small error in redshift
        print "Out of {:d} miscentered clsuters, {:d} are galaxies that DON'T BELONG to the same redMaPPer cluster."\
            .format(testn+1, num_mismatched_redM)
# Out:
# BCG index:  0
# Halo matched index: 125
# Total angular separation:  1.11431145621e-06
# RA difference:  -6.143786208667734e-07
# DEC difference:  -1.0330830804150537e-06
# IDs are  45001224046 45002111705
# Redshift difference: -0.00381956
#
# Out of 1 miscentered clsuters, 0 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  100
# Halo matched index: 22
# Total angular separation:  1.35388960136e-06
# RA difference:  1.0134542449691253e-06
# DEC difference:  -9.726018319611285e-07
# IDs are  17002384069 17004046017
# Redshift difference: 0.00578398
#
# Out of 101 miscentered clsuters, 13 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  200
# Halo matched index: 54
# Total angular separation:  1.63359335305e-06
# RA difference:  -1.315198062457057e-06
# DEC difference:  1.4601430393668124e-06
# IDs are  94001521643 94002754806
# Redshift difference: 0.00453669
#
# Out of 201 miscentered clsuters, 28 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  300
# Halo matched index: 74
# Total angular separation:  0.00115723350278
# RA difference:  0.00028791858693466565
# DEC difference:  -0.0011445850205262786
# IDs are  116003122219 116002473007
# Redshift difference: -0.00918704
#
# Out of 301 miscentered clsuters, 56 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  400
# Halo matched index: 40
# Total angular separation:  8.57563707903e-07
# RA difference:  -6.603504232316482e-07
# DEC difference:  -6.164247992046512e-07
# IDs are  34001842930 34001403597
# Redshift difference: -0.00620466
#
# Out of 401 miscentered clsuters, 84 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  500
# Halo matched index: 91
# Total angular separation:  0.00170821557797
# RA difference:  0.0003103607581103063
# DEC difference:  -0.0016818200792556581
# IDs are  377003243698 377004560405
# Redshift difference: -0.00927156
#
# Out of 501 miscentered clsuters, 108 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  600
# Halo matched index: 0
# Total angular separation:  1.97570373409e-06
# RA difference:  -2.2381543729466102e-06
# DEC difference:  -7.605925489428955e-08
# IDs are  17002719764 17002075364
# Redshift difference: -0.0030936
#
# Out of 601 miscentered clsuters, 148 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  700
# Halo matched index: 2
# Total angular separation:  1.86544635738e-06
# RA difference:  1.0429390897570556e-06
# DEC difference:  1.6780014249206943e-06
# IDs are  38002034467 38002761261
# Redshift difference: -0.0061146
#
# Out of 701 miscentered clsuters, 172 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  800
# Halo matched index: 32
# Total angular separation:  1.38096817208e-06
# RA difference:  -9.044938771296529e-07
# DEC difference:  1.2589620794756229e-06
# IDs are  110003882082 110003164383
# Redshift difference: 0.00489867
#
# Out of 801 miscentered clsuters, 195 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  900
# Halo matched index: 39
# Total angular separation:  2.43292764071e-06
# RA difference:  1.602341804129992e-06
# DEC difference:  2.3345415911535383e-06
# IDs are  54002660196 54003238755
# Redshift difference: 0.0020262
#
# Out of 901 miscentered clsuters, 236 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1000
# Halo matched index: 38
# Total angular separation:  2.27386891829e-06
# RA difference:  -2.446315761517326e-06
# DEC difference:  -1.7668507297230462e-06
# IDs are  120003909883 120001538534
# Redshift difference: 0.00330275
#
# Out of 1001 miscentered clsuters, 265 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1100
# Halo matched index: 8
# Total angular separation:  0.00229402844995
# RA difference:  0.0003301394438821603
# DEC difference:  0.0022779962061107994
# IDs are  106001984057 106002137502
# Redshift difference: -0.00151831
#
# Out of 1101 miscentered clsuters, 287 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1200
# Halo matched index: 0
# Total angular separation:  9.91113661712e-07
# RA difference:  -9.416089952196671e-07
# DEC difference:  4.968792453041715e-07
# IDs are  382002339427 382003144696
# Redshift difference: -0.00986469
#
# Out of 1201 miscentered clsuters, 319 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1300
# Halo matched index: 10
# Total angular separation:  0.00626547712977
# RA difference:  0.0068773239034314315
# DEC difference:  -0.0008083842307620159
# IDs are  18002461972 18004205665
# Redshift difference: -0.00110674
#
# Out of 1301 miscentered clsuters, 353 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1400
# Halo matched index: 2
# Total angular separation:  1.18301676759e-06
# RA difference:  9.387929864601574e-07
# DEC difference:  7.677080198220665e-07
# IDs are  6001704344 6003753639
# Redshift difference: 0.00105539
#
# Out of 1401 miscentered clsuters, 387 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1500
# Halo matched index: 39
# Total angular separation:  0.00112868296704
# RA difference:  0.0012272980976177905
# DEC difference:  -0.000570251084361928
# IDs are  105001230841 105003509916
# Redshift difference: -0.00306532
#
# Out of 1501 miscentered clsuters, 417 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1600
# Halo matched index: 31
# Total angular separation:  1.08627373361e-06
# RA difference:  9.69335360423429e-07
# DEC difference:  8.888688398656086e-07
# IDs are  109003365150 109003778670
# Redshift difference: 0.00257933
#
# Out of 1601 miscentered clsuters, 454 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1700
# Halo matched index: 21
# Total angular separation:  1.15703955409e-06
# RA difference:  -7.74670127157151e-07
# DEC difference:  9.255855353274001e-07
# IDs are  34001533648 34002540259
# Redshift difference: 0.00106737
#
# Out of 1701 miscentered clsuters, 477 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1800
# Halo matched index: 19
# Total angular separation:  0.00330792175959
# RA difference:  0.0014518173696296266
# DEC difference:  0.0031209662721138898
# IDs are  108001063486 108000000383
# Redshift difference: 0.000662297
#
# Out of 1801 miscentered clsuters, 505 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  1900
# Halo matched index: 13
# Total angular separation:  1.33513513783e-06
# RA difference:  -8.722886519763051e-07
# DEC difference:  -1.208776325256622e-06
# IDs are  45002609128 45001834960
# Redshift difference: -0.0061729
#
# Out of 1901 miscentered clsuters, 542 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2000
# Halo matched index: 41
# Total angular separation:  1.95681209815e-06
# RA difference:  1.911010066635299e-06
# DEC difference:  -5.673814946760558e-07
# IDs are  367001945449 367002110944
# Redshift difference: 0.00800341
#
# Out of 2001 miscentered clsuters, 568 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2100
# Halo matched index: 54
# Total angular separation:  0.00302323331081
# RA difference:  -0.00019010037496114407
# DEC difference:  0.0030172755073509805
# IDs are  350002506966 350002675696
# Redshift difference: 0.00913125
#
# Out of 2101 miscentered clsuters, 595 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2200
# Halo matched index: 10
# Total angular separation:  1.61302696358e-06
# RA difference:  -2.1727350372202636e-06
# DEC difference:  1.0617508863219882e-06
# IDs are  115002365307 115002676110
# Redshift difference: -0.000307441
#
# Out of 2201 miscentered clsuters, 623 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2300
# Halo matched index: 44
# Total angular separation:  0.00283991559765
# RA difference:  0.003852005492490207
# DEC difference:  0.0003328370371633582
# IDs are  37002330843 37005094563
# Redshift difference: -0.00227708
#
# Out of 2301 miscentered clsuters, 660 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2400
# Halo matched index: 74
# Total angular separation:  0.00267843893537
# RA difference:  0.0024149141062892454
# DEC difference:  0.0014855513329727899
# IDs are  17003326658 17006276470
# Redshift difference: -0.00762439
#
# Out of 2401 miscentered clsuters, 690 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2500
# Halo matched index: 5
# Total angular separation:  1.5487061314e-06
# RA difference:  1.7705788337707418e-06
# DEC difference:  -3.0630229730377323e-07
# IDs are  24002037563 24003148482
# Redshift difference: 0.00411254
#
# Out of 2501 miscentered clsuters, 713 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2600
# Halo matched index: 14
# Total angular separation:  0.00194320300492
# RA difference:  0.001703856144359861
# DEC difference:  0.0017669455148947577
# IDs are  53002509940 53002478892
# Redshift difference: 0.00581908
#
# Out of 2601 miscentered clsuters, 744 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2700
# Halo matched index: 8
# Total angular separation:  1.37923785626e-06
# RA difference:  -1.4606443272668912e-06
# DEC difference:  -2.573835935493207e-07
# IDs are  11002027717 11001793789
# Redshift difference: -0.00971937
#
# Out of 2701 miscentered clsuters, 767 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2800
# Halo matched index: 37
# Total angular separation:  0.00159669842303
# RA difference:  -0.001879101953461415
# DEC difference:  0.0004985055956865381
# IDs are  106002596366 106002724843
# Redshift difference: -0.00139886
#
# Out of 2801 miscentered clsuters, 802 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  2900
# Halo matched index: 54
# Total angular separation:  0.00140429510108
# RA difference:  0.0031414747073092997
# DEC difference:  0.0004453231415908476
# IDs are  122003098619 122004718282
# Redshift difference: -0.00216967
#
# Out of 2901 miscentered clsuters, 842 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3000
# Halo matched index: 41
# Total angular separation:  0.00125693121617
# RA difference:  -0.00017454128310845363
# DEC difference:  0.001248014148170995
# IDs are  15003014576 15004035036
# Redshift difference: -0.00716931
#
# Out of 3001 miscentered clsuters, 885 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3100
# Halo matched index: 16
# Total angular separation:  4.5343058204e-06
# RA difference:  -6.206034129263571e-06
# DEC difference:  -6.206549798548622e-07
# IDs are  92001424340 92002752848
# Redshift difference: -0.00473231
#
# Out of 3101 miscentered clsuters, 912 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3200
# Halo matched index: 40
# Total angular separation:  0.00141698690192
# RA difference:  0.0012973524112140922
# DEC difference:  -0.0009932073954743714
# IDs are  41002917260 41003715295
# Redshift difference: 0.000591874
#
# Out of 3201 miscentered clsuters, 954 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3300
# Halo matched index: 18
# Total angular separation:  0.0042229170444
# RA difference:  -0.0029336031983078215
# DEC difference:  -0.003242151708924723
# IDs are  16001662089 16002992380
# Redshift difference: -0.00599292
#
# Out of 3301 miscentered clsuters, 999 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3400
# Halo matched index: 18
# Total angular separation:  1.57508102893e-06
# RA difference:  -1.477191339915862e-06
# DEC difference:  1.2376186404594591e-06
# IDs are  49002397714 49004440021
# Redshift difference: -0.00895613
#
# Out of 3401 miscentered clsuters, 1034 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3500
# Halo matched index: 26
# Total angular separation:  2.65075016533e-06
# RA difference:  -2.4985828908086205e-06
# DEC difference:  1.0045080500731274e-06
# IDs are  376003019226 376004057473
# Redshift difference: -0.00237691
#
# Out of 3501 miscentered clsuters, 1073 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3600
# Halo matched index: 22
# Total angular separation:  6.10049547641e-06
# RA difference:  -6.090592933105654e-06
# DEC difference:  -3.631024046990561e-07
# IDs are  64003203586 64001764599
# Redshift difference: -0.00164819
#
# Out of 3601 miscentered clsuters, 1116 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3700
# Halo matched index: 20
# Total angular separation:  0.0028498708314
# RA difference:  -0.0022036826229197004
# DEC difference:  0.0018081772390827755
# IDs are  359002680256 359001945524
# Redshift difference: 0.00566989
#
# Out of 3701 miscentered clsuters, 1161 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3800
# Halo matched index: 33
# Total angular separation:  0.00126022609998
# RA difference:  0.0007867948142887826
# DEC difference:  -0.0010151874040076336
# IDs are  12001969760 12001541598
# Redshift difference: -0.00498962
#
# Out of 3801 miscentered clsuters, 1192 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  3900
# Halo matched index: 12
# Total angular separation:  1.31165588959e-06
# RA difference:  1.2574369279150233e-06
# DEC difference:  3.9933571915895527e-07
# IDs are  369002432514 369004337807
# Redshift difference: -0.00526905
#
# Out of 3901 miscentered clsuters, 1232 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4000
# Halo matched index: 9
# Total angular separation:  0.00191441460234
# RA difference:  -0.0024488847361707755
# DEC difference:  0.0009956561919750584
# IDs are  109003378333 109003793525
# Redshift difference: 0.0019334
#
# Out of 4001 miscentered clsuters, 1284 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4100
# Halo matched index: 29
# Total angular separation:  0.00345260585803
# RA difference:  0.000553771874422182
# DEC difference:  -0.0034270943186953673
# IDs are  92001423508 92002752336
# Redshift difference: 0.00826502
#
# Out of 4101 miscentered clsuters, 1335 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4200
# Halo matched index: 34
# Total angular separation:  0.00145787666938
# RA difference:  6.419161661597172e-05
# DEC difference:  -0.0014575040175017762
# IDs are  116003727668 116004296788
# Redshift difference: 0.00965041
#
# Out of 4201 miscentered clsuters, 1372 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4300
# Halo matched index: 5
# Total angular separation:  0.0016204098312
# RA difference:  0.0013258232925608127
# DEC difference:  -0.0011912540414158457
# IDs are  21002094971 21002765473
# Redshift difference: 0.00117934
#
# Out of 4301 miscentered clsuters, 1417 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4400
# Halo matched index: 11
# Total angular separation:  1.8065630999e-06
# RA difference:  5.23437552857331e-07
# DEC difference:  -1.7623227464014235e-06
# IDs are  23002353600 23003311406
# Redshift difference: -9.11951e-05
#
# Out of 4401 miscentered clsuters, 1455 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4500
# Halo matched index: 9
# Total angular separation:  1.6849646767e-06
# RA difference:  -1.924193611557712e-06
# DEC difference:  6.930447966624342e-07
# IDs are  28001761910 28002992427
# Redshift difference: 0.000560641
#
# Out of 4501 miscentered clsuters, 1496 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4600
# Halo matched index: 25
# Total angular separation:  0.000712165850945
# RA difference:  -0.0006670467347191789
# DEC difference:  -0.0004221716775809625
# IDs are  104002324913 104003290798
# Redshift difference: -0.00156701
#
# Out of 4601 miscentered clsuters, 1541 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4700
# Halo matched index: 17
# Total angular separation:  0.000422265707804
# RA difference:  -0.0002940978234562408
# DEC difference:  -0.00032859045784761065
# IDs are  14003383176 14001910144
# Redshift difference: -0.00285327
#
# Out of 4701 miscentered clsuters, 1584 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4800
# Halo matched index: 17
# Total angular separation:  3.02373668435e-06
# RA difference:  -3.0200498013499555e-06
# DEC difference:  -1.7084743042516948e-07
# IDs are  347003382329 347004104956
# Redshift difference: 0.00143695
#
# Out of 4801 miscentered clsuters, 1632 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  4900
# Halo matched index: 35
# Total angular separation:  3.88062824469e-07
# RA difference:  6.323698542587408e-07
# DEC difference:  2.143583444080832e-07
# IDs are  54002660725 54003240095
# Redshift difference: 0.00040108
#
# Out of 4901 miscentered clsuters, 1677 are galaxies that DON'T BELONG to the same redMaPPer cluster.
# BCG index:  5000
# Halo matched index: 27
# Total angular separation:  4.38238073546e-07
# RA difference:  4.572572009919895e-07
# DEC difference:  4.8724480450346164e-08
# IDs are  10000668452 10000446276
# Redshift difference: -0.00177366
#
# Out of 5001 miscentered clsuters, 1720 are galaxies that DON'T BELONG to the same redMaPPer cluster.

# %%
##To do, plot against all miscentered z difference. 
plt.hist(mismatched_z_diff, density=True, alpha=0.5, label='mismatched')
#plt.hist(BCG_miscent.Z - mat, density=True, alpha=0.5, label='All miscentered')
plt.xlabel(r'$\Delta z$')
plt.show()

# %%
plt.hist(mismatched_z, bins=10, density=True, alpha=0.5, label='mismatched')
plt.hist(BCG_miscent.Z, bins=10, density=True, alpha=0.5, label='All miscentered')
plt.xlabel('z')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show>
