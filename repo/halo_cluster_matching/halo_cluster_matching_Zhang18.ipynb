# %% [markdown]
# ## For Matching buzzard halos with redMaPPer clusters.
# ### Created Jan, 2018
# ### Zhuowen Zhang
#
# **Update April 29, 2018:**
#
# Halo files are halos_unique in Buzzard Y3 to get rid of overlapping halos in boxes with overlapping regions. Mass definition is M200b. Cosmology used for comoving distance measurements reflect
# Buzzard cosmology.
#
# **Update April 25, 2019:**
#
# 1. Use the Chinchilla-0_halos_unique_all.fits which combines all *_unique_X FITs files, so that no need to merge files for each run. Saves time.
#
#
# 2. Change of halo matching algorithm. For some clusters halos and cluster centers have exact match, when both are centerd on the BCG. The algo now only applies mass-richness priority matcihng to none (RA,DEC,Z) matched cluster/halos. This should reduce the number of miscentering from ~50% of 20,000 redM halos to something more like the real data, refer Y.Zhang et al 2019.

# %%
import numpy as np
import sys
#sys.path.append('/home/zzbenjamin94/Desktop/Astronomy/Research/DES_Galaxy_Cluster')
from tools.setup.setup import *
home_dir = home_dir()
datadir = data_home_dir()
bigdatadir = bigdata_home_dir()

# import pyplot and set some parameters to make plots prettier
import matplotlib.pyplot as plt
from tools.plot_utils import plot_pretty
plot_pretty()

# setup notebook for inline figures
# %matplotlib inline

from tools.setup.setup import *
import astropy.io.fits as fits
#Read http://pythonhosted.org/pyfits/

# %%
#Convert from z to comoving distance in fiducial cosmology
from astropy import units as u
from astropy import cosmology
from astropy.cosmology import WMAP9 as cosmo
from astropy.coordinates import SkyCoord

# %% [markdown]
# ### Extracting Halo and Cluster Files
# From buzzard and Chinchilla in Slac_Stanford simulation repository

# %%
redM_data = bigdatadir+'Buzzard_Sims/v1.6/buzzard_halo/redM/'+'buzzard-0_1.6_y3_run_redmapper_v6.4.20_lgt20_vl02_catalog.fit'
redM_list = fits.open(redM_data)
redM_data = redM_list[1].data

print "Names of columns in redM_data are: \n"
print redM_data.names

print "Number of clusters is ", len(redM_data)
print "Lambda cut is ", min(redM_data.LAMBDA_CHISQ)
# Out:
# Names of columns in redM_data are:
#
# ['MEM_MATCH_ID', 'RA', 'DEC', 'MODEL_MAG', 'MODEL_MAGERR', 'REFMAG', 'REFMAG_ERR', 'ZRED', 'ZRED_E', 'ZRED_CHISQ', 'BCG_SPEC_Z', 'Z_SPEC_INIT', 'Z_INIT', 'Z', 'LAMBDA_CHISQ', 'LAMBDA_CHISQ_E', 'LAMBDA_ZRED', 'LAMBDA_ZRED_E', 'R_LAMBDA', 'SCALEVAL', 'MASKFRAC', 'GEOMASKFRAC', 'C_LAMBDA', 'C_LAMBDA_ERR', 'MAG_LAMBDA_ERR', 'CHISQ', 'Z_LAMBDA', 'Z_LAMBDA_E', 'Z_LAMBDA_NITER', 'EBV_MEAN', 'LNLAMLIKE', 'LNBCGLIKE', 'LNLIKE', 'PZBINS', 'PZ', 'NCROSS', 'RMASK', 'RA_ORIG', 'DEC_ORIG', 'W', 'DLAMBDA_DZ', 'DLAMBDA_DZ2', 'DLAMBDAVAR_DZ', 'DLAMBDAVAR_DZ2', 'LAMBDA_CHISQ_C', 'LAMBDA_CHISQ_CE', 'NCENT', 'NCENT_GOOD', 'RA_CENT', 'DEC_CENT', 'ID_CENT', 'LAMBDA_CHISQ_CENT', 'ZLAMBDA_CENT', 'P_BCG', 'P_CEN', 'Q_CEN', 'P_FG', 'Q_MISS', 'P_SAT', 'P_C', 'BCG_ILUM', 'ILUM', 'Z_LAMBDA_RAW', 'Z_LAMBDA_E_RAW', 'LIM_EXPTIME', 'LIM_LIMMAG_DERED', 'LIM_LIMMAG', 'LIM_LIMMAG_HARD']
# Number of clusters is  24243
# Lambda cut is  19.8967

# %% [raw]
# #Reading halo files
# halo_filenum = [0,1,17,19,2,21,22,23,26,27,3,4,5,6,7]
# halo_iter = np.shape(halo_filenum)[0]
#
# #halos_data, the rec_array that combines all halo files, reads from first halo file, and then stacks to it.
# halo_data = datadir+'buzzard_halo/chinchilla/'+'Chinchilla-0_halos_unique.'+str(halo_filenum[0])+'.fits'
# halo_list = pyfits.open(halo_data)
# cols = halo_list[1].data.columns
# halos_data = pyfits.FITS_rec.from_columns(cols) #stores as record array
#
# #check that halos_data match halo_data
# print 'number of rows in halo_data/halos_data (initial) ', len(halos_data)
#
# #check that files_num has rows totaling the number of rows combined from each halo file
# tot_row = np.append(0,halos_data.shape[0])
#
# #Iterate through rest of halo files. Each iteration creates a new and updated halos_file record array
# #with new rows added that correspond to data from each halo file.
# for i in xrange(1,halo_iter):
#     halo_data = datadir+'buzzard_halo/chinchilla/'+'Chinchilla-0_halos_unique.'+str(halo_filenum[i])+'.fits'
#     halo_list = pyfits.open(halo_data)
#     halo_data = halo_list[1].data
#
#     nrows1 = halos_data.shape[0]
#     nrows2 = halo_data.shape[0]
#     nrows = nrows1 + nrows2
#     tot_row = np.append(tot_row, nrows)
#
#     #Warning: from_columns appends rows to halos_data, but does not update column array. Need to manually
#     #copy data each time. Inefficient code, but will do.
#     copy_halos_data = pyfits.FITS_rec.copy(halos_data) #Need to make copy of previous halos_data
#     halos_data = pyfits.FITS_rec.from_columns(halos_data, nrows=nrows, fill=False) #Warning: Does not update column data in halos_data
#
#     #Fill in the extra rows with data from new halo file
#     for colname in halo_data.columns.names:
#         halos_data[colname][:nrows1] = copy_halos_data[colname]
#         halos_data[colname][nrows1:] = halo_data[colname]
#     print "Halo file number ", halo_filenum[i]

# %% [raw]
# #Check that halos_file is combining the files properly.
# #For more info on record arrays, pyFITS:
# #https://pythonhosted.org/pyfits/usage/table.html#table-data-as-a-record-array
# #http://pythonhosted.org/pyfits/api/tables.html#pyfits.FITS_rec
#
# #Check 1: Field values match that in the last halo file read
# test_num = 14
# halo_data = datadir+'buzzard_halo/chinchilla/'+'Chinchilla-0_halos_unique.'+str(halo_filenum[test_num])+'.fits'
# halo_list = pyfits.open(halo_data)
# halo_data = halo_list[1].data
#
# #Check 2: The length of halos_file equals that of all halo_file rows combined.
# if tot_row[-1] == len(halos_data):
#     print "Number of rows match. It is ", len(halos_data)

# %% [markdown]
# ### Halo file

# %%
#Only record array pickle file
import pickle
halos_file = bigdatadir + 'Buzzard_Sims/v1.6/buzzard_halo/halos/' + 'Chinchilla-0_halos_unique_lensedcoord.all.fits'
halos_list = fits.open(halos_file)
halos_data = halos_list[1].data

#Checking FITS into
#hrun_list.info()
print "Names of columns in halos_data are:"
print halos_data.dtype

#Converting FITS files into record array
halos_data = np.array(halos_data, dtype=halos_data.dtype)
halos_data = halos_data.view(np.recarray)

print "\n Number of halos is", len(halos_data.HALOID)
# Out:
# Names of columns in halos_data are:
# (numpy.record, [('RA', '>f8'), ('TRA', '>f8'), ('DEC', '>f8'), ('TDEC', '>f8'), ('Z', '>f8'), ('HALOID', '>i8'), ('DESCID', '>i8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8')])
#
#  Number of halos is 11132591

# %%
unique_ID, unique_ind = np.unique(halos_data.HALOID, return_index=True)
halos_data = halos_data[unique_ind]
print "Unique halos are", len(halos_data)
# Out:
# Unique halos are 11132591

# %% [markdown]
# ### Cuts and filters
# #### Mass cut

# %%
mcut_val = 1e13
mass_cutoff = halos_data['M200B'] > mcut_val
halos_data = halos_data[mass_cutoff]
print "After mass cut of M > {} M_sun number of halos is ".format(mcut_val), len(halos_data)
# Out:
# After mass cut of M > 1e+13 M_sun number of halos is  3673888

# %% [markdown]
# ## Rotate the halo files
#
# **Update April 26, 2019**
#
# Chunhao uses np.dot(rmat.T, halos_posvec), or the transpose of that if you make halos_posvec a Nx3 matrix.
#
# It should however be np.dot(rmat, halos_posvec), no transpose.
#
# Rotation not needed if using the halo run observed coordinates.

# %%
# Rotate the halo files
import healpy as hp
import fitsio
from tools.setup.setup import tools_home_dir
import pickle

toolsdir = tools_home_dir()

#file containing the rotation matrix 
rotfile = toolsdir+'desy3_irot.pkl'

with open(rotfile, 'r') as fp:
    rmat = pickle.load(fp)

# %% [markdown]
# #### Rotate halo files

# %%
#Need to convert from ang to vec.
theta = np.pi/2 - halos_data['DEC']*np.pi/180.
phi = halos_data['RA']*np.pi/180
halos_posvec = hp.ang2vec(theta, phi).T

#Rotation
halos_rposvec = np.matmul(rmat, halos_posvec)
#halos_rposvec = np.matmul(rmat, halos_posvec)

#Rotate the Cartesian positions.
#halos_X = halos_rposvec[0]*halos_norm; halos_Y = halos_rposvec[1]*halos_norm; halos_Z = halos_rposvec[2]*halos_norm

#convert to angular coords (in degrees)
theta2, phi2 = hp.vec2ang(halos_rposvec.T)
halos_data['DEC'] = (np.pi/2 - theta2) * 180/np.pi
halos_data['RA'] = phi2 * 180/np.pi

# %% [raw]
# #Derotate the coordinates
# from numpy.linalg import inv
#
# inv_rmat = inv(rmat)
# halos_posvec2 = np.dot(inv_rmat, halos_rposvec)
# print halos_posvec2 - halos_posvec

# %%
#Scatter plot to inspect that halos match clusters
plt.figure(figsize=(4,3))
plt.scatter(redM_data['RA'], redM_data['DEC'], c='r', s=7, alpha=0.2, marker='o',linewidth=0.0, label='redMapper')
plt.scatter(halos_data['RA'][::300], halos_data['DEC'][::300], c='orange', marker='.', s=10, linewidth=0.0, alpha=0.2, label='Rotated halos')

plt.xlabel('RA'); plt.ylabel('DEC ')
plt.legend(fontsize=8, loc='upper center')
plt.title('Position of halos and clusters')
plt.tight_layout()
#plt.savefig('halo_cluster_pos.png')
plt.show()

# %% [markdown]
# ## Extract Parameters from Files

# %% [raw]
# # Distance calculations for proximity matching
# from colossus.cosmology import cosmology
#
# #Conform to Buzzard cosmology
# h = 0.70
# my_cosmo = {'flat': True, 'H0': h*100, 'Om0': 0.286, 'Ob0': 0.045714, 'sigma8': 0.82, \
#             'ns': 0.951, 'Neff':3.04}
# # set my_cosmo to be the current cosmology
# cosmo = cosmology.setCosmology('my_cosmo', my_cosmo)
#
# #Set to transverse or line of sight comoving distance? Can't tell.
# #comoving_r = cosmo.comovingDistance(zmin, zmax, transverse=True)

# %%
#RedM
redM_ID = redM_data['MEM_MATCH_ID']
redM_RA = redM_data['RA']; redM_DEC = redM_data['DEC']
redM_z = redM_data['Z_LAMBDA']
redM_lmda = redM_data['LAMBDA_CHISQ']; 

#Halos
halos_ID = halos_data['HALOID']; 
halos_RA = halos_data['RA']; 
halos_DEC = halos_data['DEC']; 
halos_z = halos_data['Z']
halos_M200b = halos_data['M200B']; halos_Mvir = halos_data['MVIR']
halos_Rvir = halos_data['RVIR'] #in kpc
halos_X = halos_data['PX']; halos_Y = halos_data['PY']; halos_Z = halos_data['PZ']

# %% [markdown]
# ## Finding miscentered clusters
#
# For those with (RA,DEC) targeted on the same BCG automatically assumes as centered. The rest are miscentered and the halo-cluster matching applies to those.
#
# Note that halos are initially unrotated and redM rotated, so this should come after rotation algo.

# %% [markdown]
# ### Testing: find least angular separation of halos with redM, using single redM clusters.

# %%
#Finding mismatch between RA, DEC, Z in halorun versus redM_galaxy
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.cosmology import WMAP9 as cosmo
from astropy.coordinates import SkyCoord

#Using find_nearest iterate through the array and find index of matched ones, also index of unmatched. 
#Go through the richness-mass template finder. 
redM_coord = SkyCoord(redM_data.RA*u.deg, redM_data.DEC*u.deg,  frame='icrs')
halos_coord = SkyCoord(halos_RA*u.deg, halos_DEC*u.deg, frame='icrs')

#Finding nearest neighbor to the halorun catalog.
def find_nearest(ind):
    dist_sep = halos_coord.separation(redM_coord[ind])
    idx = (np.abs(dist_sep)).argmin()
    return idx, dist_sep[idx].value

#Testing match of specific halo using index testn
testarr = np.arange(0,1000,100)
for i, testn in enumerate(testarr):
    ind, dist = find_nearest(testn)
    print "redM index: ", testn
    print "Halo matched index:", ind
    print "Total angular separation: ", dist
    print "RA difference: ", halos_RA[ind] -  redM_RA[testn]
    print "DEC difference: ", halos_DEC[ind] - redM_data.DEC[testn]
    #print hrun_data.Z[testn] - redM_gal_data.Z[ind] #Some error in redshift
    print "Redshift difference: {:2g} \n".format(redM_data.Z[testn] - halos_data.Z[ind]) #Small error in redshift
# Out:
# redM index:  0
# Halo matched index: 757122
# Total angular separation:  1.78605111771e-06
# RA difference:  6.93747722380067e-07
# DEC difference:  1.7075106342190338e-06
# Redshift difference: 0.00371772
#
# redM index:  100
# Halo matched index: 2783670
# Total angular separation:  0.0277930139488
# RA difference:  -0.020487577896076914
# DEC difference:  0.020535042380910085
# Redshift difference: -0.396054
#
# redM index:  200
# Halo matched index: 2457171
# Total angular separation:  3.5748299149e-07
# RA difference:  1.0884993173476687e-07
# DEC difference:  3.4819561278709443e-07
# Redshift difference: 0.00455499
#
# redM index:  300
# Halo matched index: 1990626
# Total angular separation:  3.02189818268e-06
# RA difference:  3.1838865766076196e-06
# DEC difference:  -7.713130543152147e-07
# Redshift difference: 0.00577527
#
# redM index:  400
# Halo matched index: 1840786
# Total angular separation:  7.603515473e-07
# RA difference:  -7.002481723361598e-07
# DEC difference:  3.233366392407788e-07
# Redshift difference: 0.00602999
#
# redM index:  500
# Halo matched index: 1439778
# Total angular separation:  0.00849382321487
# RA difference:  -0.008739904986201807
# DEC difference:  0.003703160307473752
# Redshift difference: 0.00326195
#
# redM index:  600
# Halo matched index: 1211506
# Total angular separation:  1.86050966581e-06
# RA difference:  -2.737579450240446e-06
# DEC difference:  -6.536235588328054e-07
# Redshift difference: 0.00900403
#
# redM index:  700
# Halo matched index: 2420492
# Total angular separation:  1.75063920863e-06
# RA difference:  1.7661280864444961e-06
# DEC difference:  3.786965407925891e-07
# Redshift difference: -0.000247687
#
# redM index:  800
# Halo matched index: 1391681
# Total angular separation:  0.0109400152522
# RA difference:  0.004251776297115484
# DEC difference:  -0.010087163880473149
# Redshift difference: 0.013285
#
# redM index:  900
# Halo matched index: 2518069
# Total angular separation:  1.55025723723e-06
# RA difference:  -1.566294422161718e-06
# DEC difference:  -3.9045544752980277e-07
# Redshift difference: 0.00261605

# %% [markdown]
# #### Running miscentering code for all clusters
# The SkyCoord coordinate matching algo takes some time to run. Few hours.

# %%
#Finding redM's nearest halo neighbor.
def find_nearest(ind):
    dist_sep = halos_coord.separation(redM_coord[ind])
    idx = (np.abs(dist_sep)).argmin()
    return idx, dist_sep[idx].value

centered_ind = [] #for clusters
cent_halo_ind = []

#Find the centered ones
ang_lim = 1e-5
z_lim = 0.1 #This shouldn't matter so long the ang_lim is small enough. 
redM_coord = SkyCoord(redM_data.RA*u.deg, redM_data.DEC*u.deg,  frame='icrs')
halos_coord = SkyCoord(halos_RA*u.deg, halos_DEC*u.deg, frame='icrs')

for i, cur_cl in enumerate(redM_data):
    cur_ID = cur_cl['MEM_MATCH_ID']
    cur_RA = cur_cl['RA']
    cur_DEC = cur_cl['DEC']
    ind, ang_sep = find_nearest(i)
    z_sep = np.abs(cur_cl['Z_LAMBDA'] - halos_z[ind])

    #ind = np.argmin(np.abs(cur_RA-halos_RA)) #this speeds up the calculation, asssuming minRA gives min_distance
    
    #halo_ID = halos_ID[ind]
    RA_val = halos_RA[ind]
    DEC_val = halos_DEC[ind]
    #ang_sep = np.sqrt((RA_val-cur_RA)**2 + (DEC_val-cur_DEC)**2)

    if (ang_sep <= ang_lim) & (z_sep <= z_lim): 
        centered_ind.append(i)
        cent_halo_ind.append(ind)
        
    if i % 10 == 0: 
        print "Processing cluster number ", i
        print "Number of centered are", len(centered_ind)
print "Total number of centered clusters are", len(centered_ind)
print "Out of total number of clusters of ", len(redM_data)
# Out:
# Processing cluster number  0
# Number of centered are 1
# Processing cluster number  10
# Number of centered are 6
# Processing cluster number  20
# Number of centered are 11
# Processing cluster number  30
# Number of centered are 16
# Processing cluster number  40
# Number of centered are 20
# Processing cluster number  50
# Number of centered are 27
# Processing cluster number  60
# Number of centered are 32
# Processing cluster number  70
# Number of centered are 41
# Processing cluster number  80
# Number of centered are 47
# Processing cluster number  90
# Number of centered are 52
# Processing cluster number  100
# Number of centered are 55
# Processing cluster number  110
# Number of centered are 60
# Processing cluster number  120
# Number of centered are 66
# Processing cluster number  130
# Number of centered are 73
# Processing cluster number  140
# Number of centered are 77
# Processing cluster number  150
# Number of centered are 81
# Processing cluster number  160
# Number of centered are 88
# Processing cluster number  170
# Number of centered are 93
# Processing cluster number  180
# Number of centered are 99
# Processing cluster number  190
# Number of centered are 104
# Processing cluster number  200
# Number of centered are 112
# Processing cluster number  210
# Number of centered are 117
# Processing cluster number  220
# Number of centered are 126
# Processing cluster number  230
# Number of centered are 134
# Processing cluster number  240
# Number of centered are 143
# Processing cluster number  250
# Number of centered are 150
# Processing cluster number  260
# Number of centered are 158
# Processing cluster number  270
# Number of centered are 165
# Processing cluster number  280
# Number of centered are 173
# Processing cluster number  290
# Number of centered are 182
# Processing cluster number  300
# Number of centered are 190
# Processing cluster number  310
# Number of centered are 197
# Processing cluster number  320
# Number of centered are 203
# Processing cluster number  330
# Number of centered are 210
# Processing cluster number  340
# Number of centered are 218
# Processing cluster number  350
# Number of centered are 224
# Processing cluster number  360
# Number of centered are 230
# Processing cluster number  370
# Number of centered are 238
# Processing cluster number  380
# Number of centered are 245
# Processing cluster number  390
# Number of centered are 251
# Processing cluster number  400
# Number of centered are 259
# Processing cluster number  410
# Number of centered are 266
# Processing cluster number  420
# Number of centered are 271
# Processing cluster number  430
# Number of centered are 278
# Processing cluster number  440
# Number of centered are 283
# Processing cluster number  450
# Number of centered are 289
# Processing cluster number  460
# Number of centered are 296
# Processing cluster number  470
# Processing cluster number  7150
# Number of centered are 4019
# Processing cluster number  7160
# Number of centered are 4023
# Processing cluster number  7170
# Number of centered are 4029
# Processing cluster number  7180
# Number of centered are 4035
# Processing cluster number  7190
# Number of centered are 4040
# Processing cluster number  7200
# Number of centered are 4043
# Processing cluster number  7210
# Number of centered are 4047
# Processing cluster number  7220
# Number of centered are 4051
# Processing cluster number  7230
# Number of centered are 4057
# Processing cluster number  7240
# Number of centered are 4062
# Processing cluster number  7250
# Number of centered are 4069
# Processing cluster number  7260
# Number of centered are 4072
# Processing cluster number  7270
# Number of centered are 4075
# Processing cluster number  7280
# Number of centered are 4079
# Processing cluster number  7290
# Number of centered are 4085
# Processing cluster number  7300
# Number of centered are 4091
# Processing cluster number  7310
# Number of centered are 4099
# Processing cluster number  7320
# Number of centered are 4104
# Processing cluster number  7330
# Number of centered are 4110
# Processing cluster number  7340
# Number of centered are 4116
# Processing cluster number  7350
# Number of centered are 4123
# Processing cluster number  7360
# Number of centered are 4130
# Processing cluster number  7370
# Number of centered are 4136
# Processing cluster number  7380
# Number of centered are 4143
# Processing cluster number  7390
# Number of centered are 4152
# Processing cluster number  7400
# Number of centered are 4157
# Processing cluster number  7410
# Number of centered are 4163
# Processing cluster number  7420
# Number of centered are 4171
# Processing cluster number  7430
# Number of centered are 4177
# Processing cluster number  7440
# Number of centered are 4182
# Processing cluster number  7450
# Number of centered are 4188
# Processing cluster number  7460
# Number of centered are 4193
# Processing cluster number  7470
# Number of centered are 4199
# Processing cluster number  7480
# Number of centered are 4203
# Processing cluster number  7490
# Number of centered are 4210
# Processing cluster number  7500
# Number of centered are 4213
# Processing cluster number  7510
# Number of centered are 4221
# Processing cluster number  7520
# Number of centered are 4227
# Processing cluster number  7530
# Number of centered are 4231
# Processing cluster number  7540
# Number of centered are 4236
# Processing cluster number  7550
# Number of centered are 4240
# Processing cluster number  7560
# Number of centered are 4244
# Processing cluster number  7570
# Number of centered are 4249
# Processing cluster number  7580
# Number of centered are 4253
# Processing cluster number  7590
# Number of centered are 4259
# Processing cluster number  7600
# Number of centered are 4266
# Processing cluster number  7610
# Number of centered are 4271
# Processing cluster number  7620
# Number of centered are 4273
# Processing cluster number  7630
# Number of centered are 4280
# Processing cluster number  7640
# Number of centered are 4282
# Processing cluster number  7650
# Number of centered are 4288
# Processing cluster number  7660
# Number of centered are 4292
# Processing cluster number  7670
# Number of centered are 4298
# Processing cluster number  7680
# Number of centered are 4301
# Processing cluster number  7690
# Number of centered are 4307
# Processing cluster number  7700
# Number of centered are 4309
# Processing cluster number  7710
# Number of centered are 4313
# Processing cluster number  7720
# Number of centered are 4319
# Processing cluster number  7730
# Number of centered are 4325
# Processing cluster number  7740
# Number of centered are 4328
# Processing cluster number  7750
# Number of centered are 4329
# Processing cluster number  7760
# Number of centered are 4334
# Processing cluster number  7770
# Number of centered are 4339
# Processing cluster number  7780
# Number of centered are 4346
# Processing cluster number  7790
# Number of centered are 4351
# Processing cluster number  7800
# Number of centered are 4355
# Processing cluster number  7810
# Number of centered are 11077
# Processing cluster number  24100
# Number of centered are 11079
# Processing cluster number  24110
# Number of centered are 11082
# Processing cluster number  24120
# Number of centered are 11085
# Processing cluster number  24130
# Number of centered are 11085
# Processing cluster number  24140
# Number of centered are 11089
# Processing cluster number  24150
# Number of centered are 11092
# Processing cluster number  24160
# Number of centered are 11095
# Processing cluster number  24170
# Number of centered are 11098
# Processing cluster number  24180
# Number of centered are 11099
# Processing cluster number  24190
# Number of centered are 11101
# Processing cluster number  24200
# Number of centered are 11101
# Processing cluster number  24210
# Number of centered are 11104
# Processing cluster number  24220
# Number of centered are 11107
# Processing cluster number  24230
# Number of centered are 11112
# Processing cluster number  24240
# Number of centered are 11112
# Total number of centered clusters are 11113
# Out of total number of clusters of  24243

# %%
from scipy.spatial import cKDTree
#Arrays of halos and clusters are one to one matched.
#Matching clusters
#cent_ind = [i for i, x in enumerate(redM_data.MEM_MATCH_ID) if x in centered_ID]
#miscent_ind = [i for i, x in enumerate(redM_data.MEM_MATCH_ID) if x not in centered_ID]
miscent_ind = np.delete(range(len(redM_data)), centered_ind)
redM_cent = redM_data[centered_ind]
redM_miscent = redM_data[miscent_ind]

print "Number of centered clusters are ", len(redM_cent)
print "Number of miscentered clusters are ", len(redM_miscent)
print "Total number of clusters are", len(redM_data)

'''
##For finding halos
#mytree.query is much faster than enumerate for 1e7 halos
HALOID_2d = np.dstack([halos_data['HALOID'],halos_data['HALOID']])[0]  # needs to be 2D arrays
mytree = cKDTree(HALOID_2d)  
dist, cent_ind = mytree.query(np.dstack([cent_halo_ID,cent_halo_ID])[0])
miscent_ind = np.delete(range(len(halos_data)), cent_ind)
halos_cent = halos_data[cent_ind]
halos_miscent = halos_data[miscent_ind]

print "\nNumber of centered halos are ", len(halos_cent)
print "Number of miscentered halos are ", len(halos_miscent)
print "Total number of halos are", len(halos_data)
'''

miscent_ind = np.delete(range(len(halos_data)), cent_halo_ind)
halos_cent = halos_data[cent_halo_ind]
halos_miscent = halos_data[miscent_ind]
print "\nNumber of centered halos are ", len(halos_cent)
print "Number of miscentered halos are ", len(halos_miscent)
print "Total number of halos are", len(halos_data)
# Out:
# Number of centered clusters are  11113
# Number of miscentered clusters are  13130
# Total number of clusters are 24243
#
# Number of centered halos are  11113
# Number of miscentered halos are  3662775
# Total number of halos are 3673888

# %% [markdown]
# ## Diagnosis plots for centered halos

# %% [markdown]
# #### Mass distribution

# %%
m_range = (1e12, 1e15)
#plt.hist(halos_data.M200B, 1000, m_range, density=True, alpha=0.5)
plt.hist(halos_cent.M200B, 10, m_range, density=True, alpha=0.5)
plt.xscale('log')
plt.show()

# %% [markdown]
# #### Redshift distribution. Introduce a cutoff at z < 0.01

# %%
#Plot the redshift difference of halos and redM
z_diff = redM_cent.Z_LAMBDA - halos_cent.Z
plt.scatter(halos_cent.M200B, z_diff, s=0.5)
plt.ylabel(r'z diff')
plt.xlabel('Mass')
#plt.ylim([-0.1,0.1])
plt.xscale('log')
plt.show()

# %% [markdown]
# #### Angular separation. Introduce cutoff at deg < 1e-5

# %%
ang_sep = np.sqrt((halos_cent.RA-redM_cent.RA)**2 + (halos_cent.DEC-redM_cent.DEC)**2)
print np.min(ang_sep), np.max(ang_sep), np.mean(ang_sep), np.median(ang_sep)
plt.scatter(halos_cent.M200B, ang_sep, s=0.5)
plt.xscale('log')
plt.show()
# Out:
# 6.8594879240788906e-09 8.80059046927708e-06 2.0680525536128464e-06 1.763829946158906e-06

# %% [markdown]
# #### Lambda-mass relation. The lambda cutoff may be reason for the sharp mass cutoff.

# %%
#Plot the lambda mass relation 
plt.scatter(halos_cent.M200B, redM_cent.LAMBDA_CHISQ, s=0.5)
plt.xscale('log')
plt.show()

# %% [markdown]
# ## Randomly select halos

# %% [markdown]
# import os
# print os.getcwd()
# print os.path.exists('/home/zzbenjamin94/Desktop/Astronomy/Research/DES_Galaxy_Cluster/output')

# %% [markdown]
# import numpy.random as rand
#
# #First apply a redshift cut, and then randomly select in that redshift.
# halos_cut = np.where((halos_data['Z']<0.90) & (halos_data['M200b'] > 1e13))
# halos_rand = halos_data[halos_cut]
#
# #Select 100,000 random samples
# num_rand = 10000
# rand_samp = rand.randint(0,len(halos_rand), num_rand)
# halos_rand = halos_rand[rand_samp]
#
# #Retreive columns
# halos_rand_ID = halos_rand['ID']; halos_rand_RA = halos_rand['RA']
# halos_rand_DEC = halos_rand['DEC']; halos_rand_z = halos_rand['Z']
#
# halos_rand_M200b = halos_rand['M200b']; halos_rand_Mvir = halos_rand['MVIR']
#
# halos_rand_Rvir = halos_rand['RVIR'] #in kpc
# halos_rand_X = halos_rand['PX']; halos_rand_Y = halos_rand['PY']; halos_rand_Z = halos_rand['PZ']
#
# #Need to convert Radius to MPC for units to work in the read_halo_particle code
# halos_rand_Rvir /= 1000

# %% [markdown]
# #### Writing to file
# For improvement, this code should check if file exists. If so write a new file.

# %% [raw]
# #Write to file
# name_str = ('halos_ID','halos_RA', 'halos_DEC', 'halos_z', 'halos_X', \
#             'halos_Y', 'halos_Z', 'halos_M200b', 'halos_Mvir', 'halos_Rvir')
# outfile = open(home_dir +'/output/buzzard/halo_rand_allz.dat','w')
# outfile.write('%12s %12s %12s %12s %12s %12s %12s %12s %12s %12s \n'%name_str)
# for i in range(num_rand):
#     outfile.write('%d %f16 %f16 %f16 %f16 %f16 %f16 %f16 %f16 %f16 \n' \
#                   %(halos_rand_ID[i], halos_rand_RA[i], halos_rand_DEC[i], halos_rand_z[i], \
#                     halos_rand_X[i], halos_rand_Y[i], halos_rand_Z[i], \
#                     halos_rand_M200b[i], halos_rand_Mvir[i], halos_rand_Rvir[i]))
# outfile.close()

# %% [markdown]
# ## IDs from the Projection Catalog
# IDs from the projection catalog as found through proximity matching to the buzzard catalog.

# %% [raw]
# # outfile = home_dir +'data/projection/proj_ID.npy'
# proj_ID = np.load(outfile)
# #Find halos in buzzard that are in the projection catalog
# ind_proj = np.isin(halos_data.ID, proj_ID)
# proj_data = halos_data[ind_proj]
# print "Number of halos in the projection catalog is (numbers should match) ", len(np.where(ind_proj==True)[0]), len(proj_ID)

# %% [raw]
# import numpy.random as rand
#
# #First apply a redshift cut, and then randomly select in that redshift.
# proj_cut = np.where((proj_data['Z']<0.90) & (proj_data['M200b'] > 1e13))
# proj_data = proj_data[proj_cut]
#
# #Retreive columns
# proj_ID = proj_data['ID']; proj_RA = proj_data['RA']
# proj_DEC = proj_data['DEC']; proj_z = proj_data['Z']
# proj_M200b = proj_data['M200b']; proj_Mvir = proj_data['MVIR']
# proj_Rvir = proj_data['RVIR'] #in kpc
# proj_X = proj_data['PX']; proj_Y = proj_data['PY']; proj_Z = proj_data['PZ']
#
# #Need to convert Radius to MPC for units to work in the read_halo_particle code
# proj_Rvir /= 1000

# %% [raw]
# #Write to file
# name_str = ('halos_ID','halos_RA', 'halos_DEC', 'halos_z', 'halos_X', \
#             'halos_Y', 'halos_Z', 'halos_M200b', 'halos_Mvir', 'halos_Rvir')
# outfile = open(home_dir +'/output/buzzard/proj_allz.dat','w')
# outfile.write('%12s %12s %12s %12s %12s %12s %12s %12s %12s %12s \n'%name_str)
# for i in range(len(proj_data.ID)):
#     outfile.write('%d %f16 %f16 %f16 %f16 %f16 %f16 %f16 %f16 %f16 \n' \
#                   %(proj_ID[i], proj_RA[i], proj_DEC[i], proj_z[i], \
#                     proj_X[i], proj_Y[i], proj_Z[i], \
#                     proj_M200b[i], proj_Mvir[i], proj_Rvir[i]))
# outfile.close()

# %% [markdown]
# ## Halo and cluster matching algorithm
# All centered clusters are automatically assigned a halo. Algorithm applies to miscentered clusters.
#
# **Important** RA, DEC need to be in radians for the matching to work. Create new array in RA, DEC. Does not change old ones.

# %%
#Extract parameters again, but only for miscentered ones. 

#Parameters for matching
redM_ID = redM_miscent['MEM_MATCH_ID']
#Convert to radians to match halos
redM_RA = redM_miscent['RA'] * np.pi/180; redM_DEC = redM_miscent['DEC'] * np.pi/180
redM_z = redM_miscent['Z_LAMBDA']
redM_lmda = redM_miscent['LAMBDA_CHISQ']; 

halos_ID = halos_miscent['HALOID']; 

##The RA, DEC have to be in radians for trig distance finder to output correct results!!
halos_RA = halos_miscent['RA'] * np.pi/180; halos_DEC = halos_miscent['DEC'] * np.pi/180; 
halos_z = halos_miscent['Z']

halos_M200b = halos_miscent['M200B']; halos_Mvir = halos_miscent['MVIR']

halos_Rvir = halos_data['RVIR'] #in kpc
halos_X = halos_miscent['PX']; halos_Y = halos_miscent['PY']; halos_Z = halos_miscent['PZ']

##Extract distance.
redM_comvr = cosmo.comoving_distance(redM_miscent.Z).value
halos_comvr = cosmo.comoving_distance(halos_miscent.Z).value

# %%
plt.scatter(halos_RA[::100], halos_DEC[::100], s=0.1)
plt.scatter(redM_RA, redM_DEC, s=0.1)
plt.show()

# %% [markdown]
# ### Halo-cluster matching algo for miscentered

# %% [markdown]
# #### Matching criterion parameters. Change to tighter or looser.

# %%
#Find clusters within redshift bin of +/- zbin. Comparing photometric z with real Z so error permitted. 
zbin = 0.05
max_d_cmvr = 2 #set to 2Mpc/h, enough to encapsulate R_\lambda for lambda=500.

# %%
#Cluster matching algorithm: Go down list of halos, 
#from most to least massive, and find potential cluster matches

#Find sorted indices for halos_M
halos_sort=np.asarray(sorted(range(len(halos_M200b)),key=lambda x:halos_M200b[x],reverse=True))
print "Number of halos is ", halos_sort.shape[0]

#Build SkyCoord distance
redM_coord = SkyCoord(redM_data.RA*u.deg, redM_data.DEC*u.deg,  frame='icrs')
halos_coord = SkyCoord(halos_RA*u.deg, halos_DEC*u.deg, frame='icrs')


cl_match_ind = np.array([]) #indices of (potentially) matched clusters 
cl_uniq_ind = np.array([]) #unique indices to select uniquely matched clusters
for i in range(halos_sort.shape[0]):
    cur_halo_RA = halos_RA[halos_sort[i]]; cur_halo_DEC = halos_DEC[halos_sort[i]]
    cur_halo_comvr = halos_comvr[halos_sort[i]]; cur_halo_z = halos_z[halos_sort[i]]
    
    #Assume clusters that fall into this redshift range have the same redshift as the halo. 
    #Find the distance to the halo according to this assumption, and find ones local to the halo.
    
    zbin_cl_ind = np.asarray(np.where(np.abs(cur_halo_z-redM_z)<zbin)[0])
    
    #Filter clusters in redshift proximity region
    redM_DEC_zfilt = redM_DEC[zbin_cl_ind]; redM_RA_zfilt = redM_RA[zbin_cl_ind]
    
    #Angle difference from RA, DEC using spherical law of cosines
    d_lmda = redM_RA_zfilt - cur_halo_RA
    d_Sigma = np.arccos(np.sin(redM_DEC_zfilt)*np.sin(cur_halo_DEC)+\
                        np.cos(redM_DEC_zfilt)*np.cos(cur_halo_DEC)*np.cos(d_lmda))
    
    #comoving distance between halo and clusters from law of cosines for clusters in same comoving distance,
    #using the halos's redshift
    d_cmvr = np.sqrt(2*cur_halo_comvr**2.*(1.-np.cos(d_Sigma)))
    
    #find eligible local clusters based on proxmity, and remove repeat cluster already taken by higher mass halos
    loc_cl_ind = zbin_cl_ind[np.where(d_cmvr<max_d_cmvr)]
    loc_cl_ind = np.setdiff1d(loc_cl_ind, cl_uniq_ind) #remove clusters already taken by higher mass halos
    
    #if local clusters present find richest one
    if np.size(loc_cl_ind) > 0:
        cur_cl_match_ind = loc_cl_ind[np.argmax(redM_lmda[loc_cl_ind])]
        cl_uniq_ind= np.append(cl_uniq_ind, cur_cl_match_ind)
    else:
        cur_cl_match_ind = -1 #-1 for no match
        
    cl_match_ind = np.concatenate((cl_match_ind, [cur_cl_match_ind]))
    
    if i%1e5 == 0:
        print "\nMatching halo number ", i
        print "Number of clusters in redshift bin is ", np.shape(zbin_cl_ind)
        print "Number of local clusters in distance range is ", np.shape(loc_cl_ind)  
        print 'Number of clusters matched to halos are ', np.shape(np.where(cl_match_ind>-1))[1]
        #print 'cl_match indices are ', np.where(cl_match_ind > -1)
        #print 'd_cmvr ', d_cmvr[0:50]
        #print 'zbin_cl_ind is ', zbin_cl_ind
        
        #Check for duplicates
        #print 'Unique clusters indices are', cl_uniq_ind
        #dupes = [x for n, x in enumerate(cl_uniq_ind) if x in cl_uniq_ind[:n]]
        #print 'Duplicate clusters are ', dupes # [[1], [3]]

print 'Number of clusters matched to halos are ', np.shape(np.where(cl_match_ind>-1))[1]
# Out:
# Number of halos is  3662775
#
# Matching halo number  0
# Number of clusters in redshift bin is  (1893,)
# Number of local clusters in distance range is  (1,)
# Number of clusters matched to halos are  1
#
# Matching halo number  100000
# Number of clusters in redshift bin is  (1233,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  4609
#
# Matching halo number  200000
# Number of clusters in redshift bin is  (4780,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  6520
#
# Matching halo number  300000
# Number of clusters in redshift bin is  (252,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  7635
#
# Matching halo number  400000
# Number of clusters in redshift bin is  (2309,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  8440
#
# Matching halo number  500000
# Number of clusters in redshift bin is  (2036,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  9082
#
# Matching halo number  600000
# Number of clusters in redshift bin is  (409,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  9598
#
# Matching halo number  700000
# Number of clusters in redshift bin is  (4562,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  10001
#
# Matching halo number  800000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  10356
#
# Matching halo number  900000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  10650
#
# Matching halo number  1000000
# Number of clusters in redshift bin is  (1956,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  10873
#
# Matching halo number  1100000
# Number of clusters in redshift bin is  (2119,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11063
#
# Matching halo number  1200000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11248
#
# Matching halo number  1300000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11390
#
# Matching halo number  1400000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11506
#
# Matching halo number  1500000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11616
#
# Matching halo number  1600000
# Number of clusters in redshift bin is  (6,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11743
#
# Matching halo number  1700000
# Number of clusters in redshift bin is  (1,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11794
#
# Matching halo number  1800000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  11929
#
# Matching halo number  1900000
# Number of clusters in redshift bin is  (1997,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12054
#
# Matching halo number  2000000
# Number of clusters in redshift bin is  (4335,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12160
#
# Matching halo number  2100000
# Number of clusters in redshift bin is  (4957,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12238
#
# Matching halo number  2200000
# Number of clusters in redshift bin is  (1,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12301
#
# Matching halo number  2300000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12341
#
# Matching halo number  2400000
# Number of clusters in redshift bin is  (4749,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12382
#
# Matching halo number  2500000
# Number of clusters in redshift bin is  (2917,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12418
#
# Matching halo number  2600000
# Number of clusters in redshift bin is  (1299,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12450
#
# Matching halo number  2700000
# Number of clusters in redshift bin is  (746,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12483
#
# Matching halo number  2800000
# Number of clusters in redshift bin is  (649,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12507
#
# Matching halo number  2900000
# Number of clusters in redshift bin is  (0,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12525
#
# Matching halo number  3000000
# Number of clusters in redshift bin is  (569,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12548
#
# Matching halo number  3100000
# Number of clusters in redshift bin is  (612,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12564
#
# Matching halo number  3200000
# Number of clusters in redshift bin is  (2034,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12579
#
# Matching halo number  3300000
# Number of clusters in redshift bin is  (544,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12597
#
# Matching halo number  3400000
# Number of clusters in redshift bin is  (515,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12614
#
# Matching halo number  3500000
# Number of clusters in redshift bin is  (852,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12626
#
# Matching halo number  3600000
# Number of clusters in redshift bin is  (1976,)
# Number of local clusters in distance range is  (0,)
# Number of clusters matched to halos are  12636
# Number of clusters matched to halos are  12646

# %%
#Sample test of mass richness using matched clusters only
halos_match_ind = np.where(cl_match_ind != -1)
halos_M200b_match = halos_M200b[halos_sort[halos_match_ind]]
#print halos_match_ind
redM_lmda_match = redM_lmda[np.asarray(cl_match_ind[halos_match_ind],dtype=int)]
plt.plot(halos_M200b_match, redM_lmda_match, '.', alpha=0.5)
plt.xscale('log')
plt.title('Halo-Cluster (match halos onto clusters only)')
#plt.ylabel(r'Richness (\lambda)'); plt.xlabel(r'Mass (M_\odot)')
#plt.tight_layout()
#plt.savefig('Halo_Cluster_clmatch_only.png')
plt.show()

# %%
#Halo matching algorithm: Go down list of redMapper clusters and find potential halo matches
#Repeat the same process for clusters. 
#Test and debug code. 

redM_sort=np.asarray(sorted(range(len(redM_lmda)),key=lambda x:redM_lmda[x],reverse=True))
print 'Number of redMapper clusters are ', len(redM_sort)
halos_match_ind = np.array([]) #indices of (potentially) matched halos 
halos_uniq_ind = np.array([])
for i in range(redM_miscent.shape[0]):
    cur_cl_RA = redM_RA[redM_sort[i]]; cur_cl_DEC = redM_DEC[redM_sort[i]]
    cur_cl_comvr = redM_comvr[redM_sort[i]]; cur_cl_z = redM_z[redM_sort[i]]
    
    #Assume clusters that fall into this redshift range have the same redshift as the halo. 
    #Find the distance to the halo according to this assumption, and find ones local to the halo.
    
    #Find clusters within redshift bin of +/- 0.05 
    zbin_halos_ind = np.asarray(np.where(np.abs(halos_z-cur_cl_z)<zbin))
    
    #Filter clusters in redshift proximity region
    halos_DEC_zfilt = halos_DEC[zbin_halos_ind]; halos_RA_zfilt = halos_RA[zbin_halos_ind]
    
    #Angle difference from RA, DEC using spherical law of cosines
    d_lmda = halos_RA_zfilt - cur_cl_RA
    d_Sigma = np.arccos(np.sin(halos_DEC_zfilt)*np.sin(cur_cl_DEC)+\
                        np.cos(halos_DEC_zfilt)*np.cos(cur_cl_DEC)*np.cos(d_lmda))
    
    #comoving distance between halo and clusters from law of cosines for clusters in same comoving distance
    d_cmvr = np.sqrt(2*cur_cl_comvr**2.*(1.-np.cos(d_Sigma)))
    
    #find local clusters
    loc_halos_ind = zbin_halos_ind[np.where(d_cmvr<max_d_cmvr)]
    loc_halos_ind = np.setdiff1d(loc_halos_ind, halos_uniq_ind) #remove halos taken by richer clusters
    
    #if local halos present find most massive one
    if np.size(loc_halos_ind) > 0:
        cur_halos_match_ind = loc_halos_ind[np.argmax(halos_M200b[loc_halos_ind])]
        halos_uniq_ind = np.append(halos_uniq_ind, cur_halos_match_ind)
    else:
        cur_halos_match_ind = -1 #-1 for no match
        
    halos_match_ind = np.concatenate((halos_match_ind, [cur_halos_match_ind]))
    
    if i%1e2 == 0:
        print "Matching cluster number ", i
        print "Number of halos in redshift bin is ", np.shape(zbin_halos_ind)
        print "Number of local halos in distance range is ", np.shape(loc_halos_ind)  
        print 'Number of halos matched to cluster are ', np.shape(np.where(cur_halos_match_ind>-1))[1]
        
        
        #print 'Halo_match indices are ', np.where(halos_match_ind > -1)
                              
        #Check for duplicates
        #print 'Unique halo indices are', halos_uniq_ind
        #dupes = [x for n, x in enumerate(cl_uniq_ind) if x in cl_uniq_ind[:n]]
        #print 'Duplicate clusters are ', dupes # [[1], [3]]

print 'Number of halos matched to clusters are ', np.shape(np.where(halos_match_ind>-1))[1]
# Out:
# Number of redMapper clusters are  13130
# Matching cluster number  0
# Number of halos in redshift bin is  (1, 311123)
# Number of local halos in distance range is  (8,)
# Number of halos matched to cluster are  1
# Matching cluster number  100
# Number of halos in redshift bin is  (1, 494920)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  200
# Number of halos in redshift bin is  (1, 375379)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  300
# Number of halos in redshift bin is  (1, 478372)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  400
# Number of halos in redshift bin is  (1, 491407)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  500
# Number of halos in redshift bin is  (1, 465456)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  600
# Number of halos in redshift bin is  (1, 422980)
# Number of local halos in distance range is  (7,)
# Number of halos matched to cluster are  1
# Matching cluster number  700
# Number of halos in redshift bin is  (1, 450224)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  800
# Number of halos in redshift bin is  (1, 471102)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  900
# Number of halos in redshift bin is  (1, 420973)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  1000
# Number of halos in redshift bin is  (1, 206706)
# Number of local halos in distance range is  (7,)
# Number of halos matched to cluster are  1
# Matching cluster number  1100
# Number of halos in redshift bin is  (1, 442554)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  1200
# Number of halos in redshift bin is  (1, 404038)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  1300
# Number of halos in redshift bin is  (1, 425357)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  1400
# Number of halos in redshift bin is  (1, 381016)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  1500
# Number of halos in redshift bin is  (1, 483740)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  1600
# Number of halos in redshift bin is  (1, 439154)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  1700
# Number of halos in redshift bin is  (1, 474659)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  1800
# Number of halos in redshift bin is  (1, 248321)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  1900
# Number of halos in redshift bin is  (1, 450518)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  2000
# Number of halos in redshift bin is  (1, 467872)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  2100
# Number of halos in redshift bin is  (1, 494997)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  2200
# Number of halos in redshift bin is  (1, 462530)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  2300
# Number of halos in redshift bin is  (1, 483026)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  2400
# Number of halos in redshift bin is  (1, 444192)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  2500
# Number of halos in redshift bin is  (1, 488415)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  2600
# Number of halos in redshift bin is  (1, 324242)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  2700
# Number of halos in redshift bin is  (1, 464925)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  2800
# Number of halos in redshift bin is  (1, 470301)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  2900
# Number of halos in redshift bin is  (1, 359447)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  3000
# Number of halos in redshift bin is  (1, 367522)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  3100
# Number of halos in redshift bin is  (1, 426924)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  3200
# Number of halos in redshift bin is  (1, 407277)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  3300
# Number of halos in redshift bin is  (1, 424841)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  3400
# Number of halos in redshift bin is  (1, 370728)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  3500
# Number of halos in redshift bin is  (1, 374562)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  3600
# Number of halos in redshift bin is  (1, 411397)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  3700
# Number of halos in redshift bin is  (1, 405276)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  3800
# Number of halos in redshift bin is  (1, 489020)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  3900
# Number of halos in redshift bin is  (1, 302993)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  4000
# Number of halos in redshift bin is  (1, 470902)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  4100
# Number of halos in redshift bin is  (1, 412615)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  4200
# Number of halos in redshift bin is  (1, 435039)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  4300
# Number of halos in redshift bin is  (1, 447850)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  4400
# Number of halos in redshift bin is  (1, 125327)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  4500
# Number of halos in redshift bin is  (1, 436394)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  4600
# Number of halos in redshift bin is  (1, 451079)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  4700
# Number of halos in redshift bin is  (1, 355234)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  4800
# Number of halos in redshift bin is  (1, 477538)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  4900
# Number of halos in redshift bin is  (1, 442673)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  5000
# Number of halos in redshift bin is  (1, 461157)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  5100
# Number of halos in redshift bin is  (1, 332986)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  5200
# Number of halos in redshift bin is  (1, 429061)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  5300
# Number of halos in redshift bin is  (1, 388144)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  5400
# Number of halos in redshift bin is  (1, 229969)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  5500
# Number of halos in redshift bin is  (1, 468165)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  5600
# Number of halos in redshift bin is  (1, 463241)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  5700
# Number of halos in redshift bin is  (1, 364910)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  5800
# Number of halos in redshift bin is  (1, 391867)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  5900
# Number of halos in redshift bin is  (1, 445848)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  6000
# Number of halos in redshift bin is  (1, 376913)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  6100
# Number of halos in redshift bin is  (1, 415326)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  6200
# Number of halos in redshift bin is  (1, 390175)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  6300
# Number of halos in redshift bin is  (1, 478424)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  6400
# Number of halos in redshift bin is  (1, 403379)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  6500
# Number of halos in redshift bin is  (1, 417769)
# Number of local halos in distance range is  (5,)
# Number of halos matched to cluster are  1
# Matching cluster number  6600
# Number of halos in redshift bin is  (1, 499437)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  6700
# Number of halos in redshift bin is  (1, 470005)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  6800
# Number of halos in redshift bin is  (1, 459854)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  6900
# Number of halos in redshift bin is  (1, 375766)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  7000
# Number of halos in redshift bin is  (1, 371541)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  7100
# Number of halos in redshift bin is  (1, 248170)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  7200
# Number of halos in redshift bin is  (1, 472459)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  7300
# Number of halos in redshift bin is  (1, 312693)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  7400
# Number of halos in redshift bin is  (1, 349009)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  7500
# Number of halos in redshift bin is  (1, 438157)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  7600
# Number of halos in redshift bin is  (1, 454444)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  7700
# Number of halos in redshift bin is  (1, 478808)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  7800
# Number of halos in redshift bin is  (1, 354779)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  7900
# Number of halos in redshift bin is  (1, 387916)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  8000
# Number of halos in redshift bin is  (1, 187234)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  8100
# Number of halos in redshift bin is  (1, 503086)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  8200
# Number of halos in redshift bin is  (1, 415178)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  8300
# Number of halos in redshift bin is  (1, 437779)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  8400
# Number of halos in redshift bin is  (1, 460516)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  8500
# Number of halos in redshift bin is  (1, 420481)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  8600
# Number of halos in redshift bin is  (1, 349180)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  8700
# Number of halos in redshift bin is  (1, 357252)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  8800
# Number of halos in redshift bin is  (1, 478541)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  8900
# Number of halos in redshift bin is  (1, 493969)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  9000
# Number of halos in redshift bin is  (1, 270845)
# Number of local halos in distance range is  (6,)
# Number of halos matched to cluster are  1
# Matching cluster number  9100
# Number of halos in redshift bin is  (1, 176817)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  9200
# Number of halos in redshift bin is  (1, 404037)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  9300
# Number of halos in redshift bin is  (1, 355337)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  9400
# Number of halos in redshift bin is  (1, 393694)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  9500
# Number of halos in redshift bin is  (1, 352613)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  9600
# Number of halos in redshift bin is  (1, 482888)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  9700
# Number of halos in redshift bin is  (1, 335670)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  9800
# Number of halos in redshift bin is  (1, 428534)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  9900
# Number of halos in redshift bin is  (1, 423786)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  10000
# Number of halos in redshift bin is  (1, 444855)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  10100
# Number of halos in redshift bin is  (1, 438343)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  10200
# Number of halos in redshift bin is  (1, 454475)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  10300
# Number of halos in redshift bin is  (1, 493892)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  10400
# Number of halos in redshift bin is  (1, 480964)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  10500
# Number of halos in redshift bin is  (1, 480275)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  10600
# Number of halos in redshift bin is  (1, 467119)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  10700
# Number of halos in redshift bin is  (1, 472550)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  10800
# Number of halos in redshift bin is  (1, 435039)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  10900
# Number of halos in redshift bin is  (1, 383035)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  11000
# Number of halos in redshift bin is  (1, 425062)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  11100
# Number of halos in redshift bin is  (1, 476577)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  11200
# Number of halos in redshift bin is  (1, 499810)
# Number of local halos in distance range is  (4,)
# Number of halos matched to cluster are  1
# Matching cluster number  11300
# Number of halos in redshift bin is  (1, 455198)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  11400
# Number of halos in redshift bin is  (1, 396497)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  11500
# Number of halos in redshift bin is  (1, 505389)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  11600
# Number of halos in redshift bin is  (1, 425389)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  11700
# Number of halos in redshift bin is  (1, 458006)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  11800
# Number of halos in redshift bin is  (1, 444725)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  11900
# Number of halos in redshift bin is  (1, 362967)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  12000
# Number of halos in redshift bin is  (1, 227591)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  12100
# Number of halos in redshift bin is  (1, 337811)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  12200
# Number of halos in redshift bin is  (1, 266994)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  12300
# Number of halos in redshift bin is  (1, 425826)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  12400
# Number of halos in redshift bin is  (1, 115462)
# Number of local halos in distance range is  (0,)
# Number of halos matched to cluster are  0
# Matching cluster number  12500
# Number of halos in redshift bin is  (1, 205010)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  12600
# Number of halos in redshift bin is  (1, 416721)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Matching cluster number  12700
# Number of halos in redshift bin is  (1, 471606)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  12800
# Number of halos in redshift bin is  (1, 431146)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  12900
# Number of halos in redshift bin is  (1, 353886)
# Number of local halos in distance range is  (1,)
# Number of halos matched to cluster are  1
# Matching cluster number  13000
# Number of halos in redshift bin is  (1, 467411)
# Number of local halos in distance range is  (3,)
# Number of halos matched to cluster are  1
# Matching cluster number  13100
# Number of halos in redshift bin is  (1, 349459)
# Number of local halos in distance range is  (2,)
# Number of halos matched to cluster are  1
# Number of halos matched to clusters are  12645

# %%
clusters_match_ind = np.where(halos_match_ind != -1)
redM_lmda_match = redM_lmda[redM_sort[clusters_match_ind]]
#print halos_match_ind
halos_M200_match = halos_M200b[np.asarray(halos_match_ind[clusters_match_ind],dtype=int)]

print np.shape(halos_M200_match), np.shape(redM_lmda_match)
plt.plot(halos_M200_match, redM_lmda_match, '.', alpha=0.5)
plt.xscale('log')
plt.title('Halo-Cluster (match clusters onto halos only)')
plt.ylabel(r'Richness ($\lambda$)'); plt.xlabel(r'Mass ($M_\odot$)')
plt.tight_layout()
#plt.savefig('Halo_Cluster_halosmatch_only.png')
plt.show()
# Out:
# (12645,) (12645,)

# %% [markdown]
# ### Debugging

# %%
#Check that in cl_match_ind the clusters matched to halos are physically adjacent. Check for redshift.
print "Check for cl_match_ind matching "
cl_match_ind_full = np.where(cl_match_ind != -1)
cl_zfilt = np.asarray(cl_match_ind[cl_match_ind_full], dtype=int)
halos_z_sorted = np.asarray(halos_z[halos_sort])
cl_zdiff =  halos_z_sorted[cl_match_ind_full] - redM_z[cl_zfilt]
#print cl_zdiff[0:50]
cl_z_excess = [x for i, x in enumerate(cl_zdiff) if x>0.05 ]
print 'Redshifts differences outside of specified range: ', len(cl_z_excess), '\n'

#Repeat same code for halos
print "Check for halos_match_ind matching "
halos_match_ind_full = np.where(halos_match_ind != -1)
halos_zfilt = np.asarray(halos_match_ind[halos_match_ind_full], dtype=int)
redM_z_sorted = np.asarray(redM_z[redM_sort])
halos_zdiff =  redM_z_sorted[halos_match_ind_full] - halos_z[halos_zfilt]
#print halos_zdiff[0:50]
halos_z_excess = [x for i, x in enumerate(halos_zdiff) if x>0.05 ]
print 'Redshifts differences outside of specified range: ', len(halos_z_excess), '\n'

#See if the unsorting algorithm works as specified. cl_match_ind and halos_match_ind have indices sorted
#by halo mass and cluster rank. Once again check for redshift. 

#Find unsorted halos to match to clusters
print "Check for redM_match_ind_unsorted matching "
a = np.asarray(cl_match_ind[cl_match_ind_full], dtype=int)
b = np.asarray(halos_sort[cl_match_ind_full], dtype=int)
cl_zdiff2 = halos_z[b] - redM_z[a]
#print cl_zdiff2[0:50]
cl_z_excess2 = [x for i, x in enumerate(cl_zdiff2) if x>0.05 ]
print 'Redshifts differences outside of specified range: ', len(cl_z_excess2), '\n'

#Find unsorted clusters to match to halos
print "Check for halos_match_ind_unsorted matching "
c = np.asarray(halos_match_ind[halos_match_ind_full], dtype=int)
d = np.asarray(redM_sort[halos_match_ind_full], dtype=int)
halos_zdiff2 = redM_z[d] - halos_z[c]
#print halos_zdiff2[0:50]
halos_z_excess2 = [x for i, x in enumerate(halos_zdiff2) if x>0.05 ]
print 'Redshifts differences outside of specified range: ', len(halos_z_excess2), '\n'

print 'Unsort full arrays and then check for match'
cl_match_ind_unsorted = np.array(cl_match_ind, dtype=int)
cl_match_ind_unsorted[halos_sort] = cl_match_ind

uniq_match_ind = np.where(cl_match_ind_unsorted != -1) #these refer to unsorted halos
uniq_match_val = cl_match_ind_unsorted[uniq_match_ind] #matched clusters to the unsorted halos
cl_zdiff3 = halos_z[uniq_match_ind] - redM_z[uniq_match_val]
#print cl_zdiff3[0:50]
cl_z_excess3 = [x for i, x in enumerate(cl_zdiff3) if x>0.05 ]
print 'Redshifts differences outside of specified range: ', len(cl_z_excess3), '\n'

print "Check that uniq_match_ind are indeed same halos, albeit in wrong order"
a = halos_z[uniq_match_ind]
b = halos_z_sorted[cl_match_ind_full]
c = np.setdiff1d(a,b)
print 'Different halos in sorted and unsorted (order does not matter)', len(c)
# Out:
# Check for cl_match_ind matching
# Redshifts differences outside of specified range:  0
#
# Check for halos_match_ind matching
# Redshifts differences outside of specified range:  0
#
# Check for redM_match_ind_unsorted matching
# Redshifts differences outside of specified range:  0
#
# Check for halos_match_ind_unsorted matching
# Redshifts differences outside of specified range:  0
#
# Unsort full arrays and then check for match
# Redshifts differences outside of specified range:  0
#
# Check that uniq_match_ind are indeed same halos, albeit in wrong order
# Different halos in sorted and unsorted (order does not matter) 0

# %% [markdown]
# ### Uniqueness matching algorithm
# If a cluster matches onto a halo, and that halo matches onto the same cluster.

# %%
cl_match_ind_unsorted = np.array(cl_match_ind, dtype=int)
cl_match_ind_unsorted[halos_sort] = cl_match_ind
halos_match_ind_unsorted = np.array(halos_match_ind, dtype=int)
halos_match_ind_unsorted[redM_sort] = halos_match_ind

uniq_match_ind = np.where(cl_match_ind_unsorted != -1) #these refer to unsorted halos
uniq_match_val = cl_match_ind_unsorted[uniq_match_ind] #matched clusters to the unsorted halos
nonuniq_match_val = [x for x in range(len(halos_match_ind_unsorted)) if x not in uniq_match_val] #assign all non_uniq halos to -1
uniq_match_bool = halos_match_ind_unsorted[uniq_match_val] == uniq_match_ind
uniq_match_bool = uniq_match_bool[0]
print 'Number of one way clusters matched to halos are ', np.shape(halos_match_ind_unsorted[uniq_match_val])
print 'Number of unique matches are ',np.shape(np.where(uniq_match_bool == True))

a = np.array(halos_match_ind_unsorted[uniq_match_val])
np.place(a , uniq_match_bool==False, -1)
halos_match_ind_unsorted[uniq_match_val] = a
halos_match_ind_unsorted[nonuniq_match_val] = -1
halos_uniq_ind_unsorted = np.copy(halos_match_ind_unsorted)

#Final cuts
redM_cut = np.where(halos_uniq_ind_unsorted != -1)
halos_cut = halos_uniq_ind_unsorted[redM_cut]

print 'After cutting out non-unique matched number of unique matches are', np.shape(np.where(halos_uniq_ind_unsorted != -1))
# Out:
# Number of one way clusters matched to halos are  (12646,)
# Number of unique matches are  (1, 12545)
# After cutting out non-unique matched number of unique matches are (1, 12545)

# %%
redM_lmda_uniq = redM_lmda[redM_cut]
halos_M200b_uniq = halos_M200b[halos_cut]

plt.plot(halos_M200b_uniq, redM_lmda_uniq, '.', alpha=0.5)
plt.xscale('log'); plt.yscale('log')
plt.title('Halo-Cluster (Uniquess two way matching)')
plt.ylabel(r'Richness ($\lambda$)'); plt.xlabel(r'Mass ($M_\odot$)')
plt.tight_layout()
#plt.savefig('Halo_Cluster_unique.png')
plt.show()

# %% [markdown]
# ## Merging data
#
# Add a centered_flag to tell whether the matching is done automatically by centering, or after having through the proximity matching

# %%
redM_miscent_matched = redM_miscent[redM_cut]
halos_miscent_matched = halos_miscent[halos_cut]

print "Number of matched miscentered: ", len(redM_miscent_matched), len(halos_miscent_matched)
print "Number of matched centered: ", len(redM_cent), len(halos_cent)
# Out:
# Number of matched miscentered:  12545 12545
# Number of matched centered:  11113 11113

# %%
#https://stackoverflow.com/questions/1201817/adding-a-field-to-a-structured-numpy-array
def add_field(a, descr):
    """Return a new array that is like "a", but has additional fields.

    Arguments:
      a     -- a structured numpy array
      descr -- a numpy type description of the new fields

    The contents of "a" are copied over to the appropriate fields in
    the new array, whereas the new fields are uninitialized.  The
    arguments are not modified.

    >>> sa = numpy.array([(1, 'Foo'), (2, 'Bar')], \
                         dtype=[('id', int), ('name', 'S3')])
    >>> sa.dtype.descr == numpy.dtype([('id', int), ('name', 'S3')])
    True
    >>> sb = add_field(sa, [('score', float)])
    >>> sb.dtype.descr == numpy.dtype([('id', int), ('name', 'S3'), \
                                       ('score', float)])
    True
    >>> numpy.all(sa['id'] == sb['id'])
    True
    >>> numpy.all(sa['name'] == sb['name'])
    True
    """
    if a.dtype.fields is None:
        raise ValueError, "`A' must be a structured numpy array"
    b = np.empty(a.shape, dtype=a.dtype.descr + descr)
    for name in a.dtype.names:
        b[name] = a[name]
    return b

#Adding centered_flag
centered_flag = [('centered_flag', int)]
matching_ID = [('matching_ID', int)]

redM_miscent_matched = add_field(redM_miscent_matched, centered_flag)
redM_miscent_matched = add_field(redM_miscent_matched, matching_ID)
redM_miscent_matched['centered_flag'] = 0

#For centered
redM_cent = add_field(redM_cent, centered_flag)
redM_cent = add_field(redM_cent, matching_ID)
redM_cent['centered_flag'] = 1

#For halos
halos_miscent_matched = add_field(halos_miscent_matched, matching_ID)
halos_cent = add_field(halos_cent, matching_ID)

# %%
#Merging the two
redM_matched = np.append(redM_cent, redM_miscent_matched)
halos_matched = np.append(halos_cent, halos_miscent_matched)

#Assign unique matching ID
matching_IDs = range(0, len(redM_matched))
redM_matched['matching_ID'] = matching_IDs
halos_matched['matching_ID'] = matching_IDs

#Convert RVIR from kpc to MPc
halos_matched['RVIR'] /= 1000.

print redM_matched.dtype
print halos_matched.dtype
# Out:
# [('MEM_MATCH_ID', '>i4'), ('RA', '>f8'), ('DEC', '>f8'), ('MODEL_MAG', '>f4', (4,)), ('MODEL_MAGERR', '>f4', (4,)), ('REFMAG', '>f4'), ('REFMAG_ERR', '>f4'), ('ZRED', '>f4'), ('ZRED_E', '>f4'), ('ZRED_CHISQ', '>f4'), ('BCG_SPEC_Z', '>f4'), ('Z_SPEC_INIT', '>f4'), ('Z_INIT', '>f4'), ('Z', '>f4'), ('LAMBDA_CHISQ', '>f4'), ('LAMBDA_CHISQ_E', '>f4'), ('LAMBDA_ZRED', '>f4'), ('LAMBDA_ZRED_E', '>f4'), ('R_LAMBDA', '>f4'), ('SCALEVAL', '>f4'), ('MASKFRAC', '>f4'), ('GEOMASKFRAC', '>f4'), ('C_LAMBDA', '>f4', (3,)), ('C_LAMBDA_ERR', '>f4', (3,)), ('MAG_LAMBDA_ERR', '>f4', (4,)), ('CHISQ', '>f4'), ('Z_LAMBDA', '>f4'), ('Z_LAMBDA_E', '>f4'), ('Z_LAMBDA_NITER', '>i2'), ('EBV_MEAN', '>f4'), ('LNLAMLIKE', '>f4'), ('LNBCGLIKE', '>f4'), ('LNLIKE', '>f4'), ('PZBINS', '>f4', (21,)), ('PZ', '>f4', (21,)), ('NCROSS', '>i2'), ('RMASK', '>f4'), ('RA_ORIG', '>f8'), ('DEC_ORIG', '>f8'), ('W', '>f4'), ('DLAMBDA_DZ', '>f4'), ('DLAMBDA_DZ2', '>f4'), ('DLAMBDAVAR_DZ', '>f4'), ('DLAMBDAVAR_DZ2', '>f4'), ('LAMBDA_CHISQ_C', '>f4'), ('LAMBDA_CHISQ_CE', '>f4'), ('NCENT', '>i2'), ('NCENT_GOOD', '>i2'), ('RA_CENT', '>f8', (5,)), ('DEC_CENT', '>f8', (5,)), ('ID_CENT', '>i8', (5,)), ('LAMBDA_CHISQ_CENT', '>f4', (5,)), ('ZLAMBDA_CENT', '>f4', (5,)), ('P_BCG', '>f4', (5,)), ('P_CEN', '>f4', (5,)), ('Q_CEN', '>f4', (5,)), ('P_FG', '>f4', (5,)), ('Q_MISS', '>f4'), ('P_SAT', '>f4', (5,)), ('P_C', '>f4', (5,)), ('BCG_ILUM', '>f4'), ('ILUM', '>f4'), ('Z_LAMBDA_RAW', '>f4'), ('Z_LAMBDA_E_RAW', '>f4'), ('LIM_EXPTIME', '>f4'), ('LIM_LIMMAG_DERED', '>f4'), ('LIM_LIMMAG', '>f4'), ('LIM_LIMMAG_HARD', '>f4'), ('centered_flag', '<i8'), ('matching_ID', '<i8')]
# [('RA', '>f8'), ('TRA', '>f8'), ('DEC', '>f8'), ('TDEC', '>f8'), ('Z', '>f8'), ('HALOID', '>i8'), ('DESCID', '>i8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8'), ('matching_ID', '<i8')]

# %%
plt.scatter(halos_matched['RA'], halos_matched['DEC'], s=1, alpha=0.2, color='red')
plt.scatter(redM_matched['RA'], redM_matched['DEC'], s=0.5, alpha=0.2, color='blue')
plt.show()

# %%
centered = np.where(redM_matched['centered_flag'] == 1)
miscentered = np.where(redM_matched['centered_flag'] == 0)

plt.scatter(halos_matched[centered]['M200B'], redM_matched[centered]['LAMBDA_CHISQ'], s=0.5, alpha=0.5, color='red')
plt.scatter(halos_matched[miscentered]['M200B'], redM_matched[miscentered]['LAMBDA_CHISQ'], s=0.5, alpha=0.2, color='blue')
plt.xscale('log'); plt.yscale('log')
plt.show()

# %%
plt.hist(halos_matched[centered]['M200B'], bins=1000, alpha=0.5, color='red')
plt.hist(halos_matched[miscentered]['M200B'], bins=1000, alpha=0.5, color='blue')
plt.xscale('log')
plt.show()

# %% [markdown]
# ## Outputting into pickle file.

# %%
import pickle
redM_file = 'redM_matched_v1.4_redMv1.6'
outfile = open(redM_file, 'wb')
pickle.dump(redM_matched, outfile)
outfile.close()

halos_file = 'halos_matched_v1.4_redMv1.6'
outfile = open(halos_file, 'wb')
pickle.dump(halos_matched, outfile)
outfile.close()

# %% [raw]
# from tools.setup.setup import home_dir
# homedir = home_dir()
#
# redM_ID_cut = redM_ID[redM_cut]; redM_RA_cut = redM_RA[redM_cut]; redM_DEC_cut = redM_DEC[redM_cut]; redM_z_cut = redM_z[redM_cut]; redM_lmda_cut = redM_lmda[redM_cut]
# halos_ID_cut = halos_ID[halos_cut]; halos_RA_cut = halos_RA[halos_cut]; halos_DEC_cut = halos_DEC[halos_cut]; halos_z_cut = halos_z[halos_cut];
# halos_M200b_cut = halos_M200b[halos_cut]; halos_Mvir_cut = halos_Mvir[halos_cut]
# halos_Rvir_cut = halos_Rvir[halos_cut]; halos_X_cut = halos_X[halos_cut]; halos_Y_cut = halos_Y[halos_cut]; halos_Z_cut = halos_Z[halos_cut]
# #RA,DEC are in rad. Convert back to degrees
# redM_RA_cut *= 180./np.pi; redM_DEC_cut *= 180./np.pi; halos_RA_cut *= 180./np.pi; halos_DEC_cut *= 180./np.pi
#
# #halos_RVir in Kpc/h. Convert to Mpc/h
# halos_Rvir_cut /= 1000
#
# name_str = ('redM_ID', 'redM_RA', 'redM_DEC', 'redM_z', 'redM_lmda', \
#             'halos_ID', 'halos_RA', 'halos_DEC', 'halos_z', 'halos_X', 'halos_Y', 'halos_Z', \
#             'halos_M200b', 'halos_Mvir', 'halos_Rvir')
# outfile = open(homedir+'/output/buzzard/halo_redM_matched.dat','w')
# outfile.write('%12s %12s %12s %12s %12s %12s %12s %12s %12s %12s %12s %12s %12s %12s %12s \n'%name_str)
#
# match_num = len(redM_ID_cut)
# for i in range(match_num):
#     outfile.write('%d %f8 %f8 %f8 %f8 %d %f8 %f8 %f8 %f8 %f8 %f8 %f8 %f8 %f8 \n' \
#                   %(redM_ID_cut[i], redM_RA_cut[i], redM_DEC_cut[i], redM_z_cut[i], redM_lmda_cut[i], \
#                    halos_ID_cut[i], halos_RA_cut[i], halos_DEC_cut[i], halos_z_cut[i], \
#                     halos_X_cut[i], halos_Y_cut[i], halos_Z_cut[i], halos_M200b_cut[i], halos_Mvir_cut[i], halos_Rvir_cut[i]))
#
# outfile.close()

# %% [raw]
# #Check that data is properly stored.
# homedir = home_dir()
# redM_dir = homedir + 'output/buzzard/'+'halo_redM_matched.dat'
#
# #Field names of the files from first row of file. Shoule be:
# #('redM_ID', 'redM_RA', 'redM_DEC', 'redM_z', 'redM_lmda', 'halos_ID', 'halos_RA', 'halos_DEC',
# #'halos_z', 'halos_X', 'halos_Y', 'halos_Z', 'halos_M200b', 'halos_Mvir', 'halos_Rvir')
# redM_halos = np.genfromtxt(redM_dir, dtype ="i, f8, f8, f8, f8, i, f8, f8, f8, f8, f8, f8, f8, f8, f8", \
#                   unpack=True, usecols=range(0,15), names=True)
#
# redM_halos = redM_halos.view(np.recarray)
# print redM_halos.dtype, np.shape(redM_halos)
