# %% [markdown]
# ## Match the BCGs of two catalogs by proximity method.
# The BCGs in the redM_halos_fullmatchingparams_matchingv1.2_Buzzardv1.6.data catalog have wrong halo IDs. This is from expressing long integer IDs with i4, creating overflow error. This includes the GALAXY ID and HALOID. Everything else about the BCGs, including location and matched halos should be okay as they are not affected by this overflow error problem.
#
# The BCGs in the catalog BCG_v1.6_info.data have correct IDs.
#
# Patch the IDs in BCG_v1.6_info.data onto the fullmatchingparams catalog through (RA, DEC,Z) matching. There should be a one-to-one correspondance.

# %%
import numpy as np
import sys
sys.path.append('/home/zzbenjamin94/Desktop/Astronomy/Research/DES_Galaxy_Cluster')

# import pyplot and set some parameters to make plots prettier
import matplotlib.pyplot as plt
from tools.plot_utils import plot_pretty
import pickle
plot_pretty()

# setup notebook for inline figures
# %matplotlib inline

from tools.setup.setup import data_home_dir, home_dir, bigdata_home_dir
import astropy.io.fits as fits

datadir = data_home_dir()
homedir = home_dir()
bigdatadir = bigdata_home_dir()
# Out:
# /home/zzbenjamin94/Desktop/Astronomy/Research/DES_Galaxy_Cluster/data/
# /data/DES/Cluster/

# %% [markdown]
# ## Import the redM matched BCG/halo catalog

# %%
#Miscentering cut
import pickle

redM_halos = homedir + 'output/buzzard/redM_halos_fullmatchingparams_matchingv1.2_Buzzardv1.6.data'

infile = open(redM_halos,'rb')
redM_halos = pickle.load(infile)
infile.close()

redM_halos = redM_halos.view(np.recarray)
print redM_halos.dtype

#Change record array dtype. 
redM_halos = redM_halos.astype([('GALAXY_ID', int), ('HALOID', int), ('DESCID', '>i8'), \
                   ('RA_OBS', '>f8'), ('DEC_OBS', '>f8'), ('TRA', '>f8'), ('TDEC', '>f8'), \
                   ('Z', '>f8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), \
                   ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), \
                   ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), \
                   ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), \
                   ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), \
                   ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), \
                   ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), \
                   ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8'), ('matching_ID', '<i8'), \
                   ('MEM_MATCH_ID', '<i8'), ('LAMBDA_CHISQ', '<f8'), ('RA_REDM', '<f8'), \
                   ('DEC_REDM', '<f8'), ('q', '<f8'), ('s', '<f8'), ('cosi', '<f8'), ('centered_flag', '<i8')])

print "Change ID from i4 to i8"
print redM_halos.dtype
# Out:
# (numpy.record, [('GALAXY_ID', '>i4'), ('HALOID', '>i4'), ('DESCID', '>i8'), ('RA_OBS', '>f8'), ('DEC_OBS', '>f8'), ('TRA', '>f8'), ('TDEC', '>f8'), ('Z', '>f8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8'), ('matching_ID', '<i8'), ('MEM_MATCH_ID', '<i8'), ('LAMBDA_CHISQ', '<f8'), ('RA_REDM', '<f8'), ('DEC_REDM', '<f8'), ('q', '<f8'), ('s', '<f8'), ('cosi', '<f8'), ('centered_flag', '<i8')])
# Change ID from i4 to i8
# (numpy.record, [('GALAXY_ID', '<i8'), ('HALOID', '<i8'), ('DESCID', '>i8'), ('RA_OBS', '>f8'), ('DEC_OBS', '>f8'), ('TRA', '>f8'), ('TDEC', '>f8'), ('Z', '>f8'), ('MVIR', '>f8'), ('VMAX', '>f8'), ('VRMS', '>f8'), ('RVIR', '>f8'), ('RS', '>f8'), ('NP', '>f8'), ('PX', '>f8'), ('PY', '>f8'), ('PZ', '>f8'), ('VX', '>f8'), ('VY', '>f8'), ('VZ', '>f8'), ('JX', '>f8'), ('JY', '>f8'), ('JZ', '>f8'), ('SPIN', '>f8'), ('RS_KLYPIN', '>f8'), ('MVIR_ALL', '>f8'), ('M200B', '>f8'), ('M200C', '>f8'), ('M500C', '>f8'), ('M2500C', '>f8'), ('XOFF', '>f8'), ('VOFF', '>f8'), ('SPIN_BULLOCK', '>f8'), ('B_TO_A', '>f8'), ('C_TO_A', '>f8'), ('PID', '>i8'), ('LUMTOT', '>f8'), ('LUM20', '>f8'), ('LBCG', '>f8'), ('NGALS', '>i8'), ('N18', '>i8'), ('N19', '>i8'), ('N20', '>i8'), ('N21', '>i8'), ('N22', '>i8'), ('matching_ID', '<i8'), ('MEM_MATCH_ID', '<i8'), ('LAMBDA_CHISQ', '<f8'), ('RA_REDM', '<f8'), ('DEC_REDM', '<f8'), ('q', '<f8'), ('s', '<f8'), ('cosi', '<f8'), ('centered_flag', '<i8')])

# %% [markdown]
# ## Import the BCG catalog with correct ID.

# %%
BCG_filename = datadir + 'v1.6/BCG_v1.6_info.data' 
BCG_file = open(BCG_filename, "rb" )
BCG_data = pickle.load(BCG_file)
BCG_data = BCG_data.view(np.recarray)
print BCG_data.dtype
# Out:
# (numpy.record, [('ID', '<i8'), ('HALOID', '<i8'), ('RA', '<f4'), ('TRA', '<f4'), ('DEC', '<f4'), ('TDEC', '<f4'), ('Z', '<f4')])
# [  16116524   16117071   16116541 ... 1008003775 1005616374 1005625859]

# %% [markdown]
# ## Match BCG_v1.6_info with fullmatchingparams catalog using (RA, DEC, Z)

# %%
# Finding mismatch between RA, DEC, Z in halorun versus BCG_galaxy
from astropy.coordinates import SkyCoord
from astropy import units as u
from astropy.cosmology import WMAP9 as cosmo
from astropy.coordinates import SkyCoord

#Using find_nearest iterate through the array and find index of matched ones, also index of unmatched. 
#Go through the richness-mass template finder. 
BCG_coord = SkyCoord(BCG_data.TRA*u.deg, BCG_data.TDEC*u.deg,  frame='icrs')
halos_coord = SkyCoord(redM_halos.TRA*u.deg, redM_halos.TDEC*u.deg, frame='icrs')

#Finding nearest neighbor to the halorun catalog.
def find_nearest(ind):
    dist_sep = BCG_coord.separation(halos_coord[ind])
    idx = (np.abs(dist_sep)).argmin()
    return idx, dist_sep[idx].value

#Testing match of specific halo using index testn
testarr = np.arange(0,1000,5)
for i, testn in enumerate(testarr):
    ind, dist = find_nearest(testn)
    print "BCG index: ", testn
    print "Halo matched index:", ind
    print "Total angular separation: ", dist
    print "RA difference: ", redM_halos.TRA[ind] -  BCG_data.TRA[testn]
    print "DEC difference: ", redM_halos.TDEC[ind] - BCG_data.TDEC[testn]
    #print hrun_data.Z[testn] - redM_gal_data.Z[ind] #Some error in redshift
    print "Redshift difference: {:2g} \n".format(BCG_data.Z[testn] - redM_halos.Z[ind]) #Small error in redshift
# Out:
# BCG index:  0
# Halo matched index: 9488
# Total angular separation:  1.58970715236
# RA difference:  1.0035400390625
# DEC difference:  -1.2379775047302246
# Redshift difference: -0.305633
#
# BCG index:  5
# Halo matched index: 9711
# Total angular separation:  2.24399529643
# RA difference:  0.3325653076171875
# DEC difference:  -2.2195606231689453
# Redshift difference: -0.220893
#
# BCG index:  10
# Halo matched index: 2729
# Total angular separation:  1.21503105396
# RA difference:  -0.1412811279296875
# DEC difference:  -1.2068824768066406
# Redshift difference: -0.151196
#
# BCG index:  15
# Halo matched index: 9711
# Total angular separation:  1.66887706805
# RA difference:  -0.169158935546875
# DEC difference:  -1.6603913307189941
# Redshift difference: -0.222674
#
# BCG index:  20
# Halo matched index: 3142
# Total angular separation:  0.211968956764
# RA difference:  0.09075927734375
# DEC difference:  -0.19170808792114258
# Redshift difference: -0.0910481
#
# BCG index:  25
# Halo matched index: 2729
# Total angular separation:  1.65013363308
# RA difference:  -0.6409759521484375
# DEC difference:  -1.5221619606018066
# Redshift difference: -0.151224
#
# BCG index:  30
# Halo matched index: 9711
# Total angular separation:  0.28426047072
# RA difference:  0.257965087890625
# DEC difference:  -0.12210941314697266
# Redshift difference: -0.235407
#
# BCG index:  35
# Halo matched index: 9711
# Total angular separation:  1.22612861011
# RA difference:  -0.11688232421875
# DEC difference:  -1.2206110954284668
# Redshift difference: -0.223968
#
# BCG index:  40
# Halo matched index: 9488
# Total angular separation:  0.216475445104
# RA difference:  -0.2175750732421875
# DEC difference:  0.001064300537109375
# Redshift difference: -0.310981
#
# BCG index:  45
# Halo matched index: 5814
# Total angular separation:  0.369721667177
# RA difference:  -0.32904052734375
# DEC difference:  0.169661283493042
# Redshift difference: -0.201671
#
# BCG index:  50
# Halo matched index: 732
# Total angular separation:  3.8485700346
# RA difference:  -0.16534423828125
# DEC difference:  -3.845078468322754
# Redshift difference: -0.339098
#
# BCG index:  55
# Halo matched index: 9711
# Total angular separation:  0.974228561758
# RA difference:  -0.245391845703125
# DEC difference:  -0.9431777000427246
# Redshift difference: -0.247933
#
# BCG index:  60
# Halo matched index: 12117
# Total angular separation:  0.604346848475
# RA difference:  -0.593109130859375
# DEC difference:  0.1290884017944336
# Redshift difference: -0.373969
#
# BCG index:  65
# Halo matched index: 6866
# Total angular separation:  0.3506078178
# RA difference:  -0.330810546875
# DEC difference:  -0.11726808547973633
# Redshift difference: -0.389161
#
# BCG index:  70
# Halo matched index: 9260
# Total angular separation:  0.63538063431
# RA difference:  -0.39739990234375
# DEC difference:  -0.49724483489990234
# Redshift difference: -0.430365
#
# BCG index:  75
# Halo matched index: 9711
# Total angular separation:  1.68285634723
# RA difference:  -0.3060760498046875
# DEC difference:  -1.6551470756530762
# Redshift difference: -0.224139
#
# BCG index:  80
# Halo matched index: 9260
# Total angular separation:  0.398191440598
# RA difference:  -0.1886749267578125
# DEC difference:  -0.35111379623413086
# Redshift difference: -0.390129
#
# BCG index:  85
# Halo matched index: 9711
# Total angular separation:  2.4062118433
# RA difference:  0.4784698486328125
# DEC difference:  -2.3588485717773438
# Redshift difference: -0.217359
#
# BCG index:  90
# Halo matched index: 9711
# Total angular separation:  1.24353848308
# RA difference:  -0.090301513671875
# DEC difference:  -1.2402944564819336
# Redshift difference: -0.223589
#
# BCG index:  95
# Halo matched index: 9488
# Total angular separation:  2.24164579514
# RA difference:  -0.1986083984375
# DEC difference:  -2.2329583168029785
# Redshift difference: -0.326702
#
# BCG index:  100
# Halo matched index: 2271
# Total angular separation:  0.407127607993
# RA difference:  0.4073638916015625
# DEC difference:  0.035820960998535156
# Redshift difference: -0.376044
#
# BCG index:  105
# Halo matched index: 9488
# Total angular separation:  2.20550099723
# RA difference:  -0.2820587158203125
# DEC difference:  -2.187652587890625
# Redshift difference: -0.310354
#
# BCG index:  110
# Halo matched index: 10669
# Total angular separation:  0.402362300423
# RA difference:  0.2552490234375
# DEC difference:  -0.31159543991088867
# Redshift difference: -0.273877
#
# BCG index:  115
# Halo matched index: 9711
# Total angular separation:  1.72927086857
# RA difference:  0.40985107421875
# DEC difference:  -1.6806368827819824
# Redshift difference: -0.229349
#
# BCG index:  120
# Halo matched index: 9711
# Total angular separation:  2.14481618851
# RA difference:  0.5333709716796875
# DEC difference:  -2.0783677101135254
# Redshift difference: -0.22095
#
# BCG index:  125
# Halo matched index: 1831
# Total angular separation:  0.161002302882
# RA difference:  0.08099365234375
# DEC difference:  -0.1392374038696289
# Redshift difference: -0.398893
#
# BCG index:  130
# Halo matched index: 732
# Total angular separation:  2.78962333293
# RA difference:  -0.6348114013671875
# DEC difference:  -2.7175283432006836
# Redshift difference: -0.330347
#
# BCG index:  135
# Halo matched index: 9488
# Total angular separation:  1.1973358755
# RA difference:  -0.658233642578125
# DEC difference:  -1.0027580261230469
# Redshift difference: -0.311302
#
# BCG index:  140
# Halo matched index: 1828
# Total angular separation:  0.826974962032
# RA difference:  -0.0903778076171875
# DEC difference:  -0.8220682144165039
# Redshift difference: -0.340139
#
# BCG index:  145
# Halo matched index: 732
# Total angular separation:  2.58335958721
# RA difference:  0.2588653564453125
# DEC difference:  -2.570545196533203
# Redshift difference: -0.355713
#
# BCG index:  150
# Halo matched index: 6866
# Total angular separation:  0.207297098066
# RA difference:  0.04901123046875
# DEC difference:  -0.20143461227416992
# Redshift difference: -0.389198
#
# BCG index:  155
# Halo matched index: 5235
# Total angular separation:  0.755910073019
# RA difference:  -0.614227294921875
# DEC difference:  0.4413912296295166
# Redshift difference: -0.37432
#
# BCG index:  160
# Halo matched index: 9711
# Total angular separation:  0.226297292018
# RA difference:  0.20733642578125
# DEC difference:  -0.09295988082885742
# Redshift difference: -0.235227
#
# BCG index:  165
# Halo matched index: 5290
# Total angular separation:  0.237510022628
# RA difference:  0.2292633056640625
# DEC difference:  0.06439781188964844
# Redshift difference: -0.292322
#
# BCG index:  170
# Halo matched index: 9488
# Total angular separation:  3.31985577095
# RA difference:  -0.9532318115234375
# DEC difference:  -3.1824440956115723
# Redshift difference: -0.302158
#
# BCG index:  175
# Halo matched index: 9711
# Total angular separation:  2.14683384671
# RA difference:  0.611419677734375
# DEC difference:  -2.059154987335205
# Redshift difference: -0.220676
#
# BCG index:  180
# Halo matched index: 9488
# Total angular separation:  2.17852304004
# RA difference:  -0.3610076904296875
# DEC difference:  -2.1488375663757324
# Redshift difference: -0.311236
#
# BCG index:  185
# Halo matched index: 9711
# Total angular separation:  0.414557705959
# RA difference:  0.4138031005859375
# DEC difference:  -0.04777717590332031
# Redshift difference: -0.236707
#
# BCG index:  190
# Halo matched index: 732
# Total angular separation:  3.00565228658
# RA difference:  -0.3837432861328125
# DEC difference:  -2.981433868408203
# Redshift difference: -0.33714
#
# BCG index:  195
# Halo matched index: 3277
# Total angular separation:  0.56406371244
# RA difference:  -0.371734619140625
# DEC difference:  -0.42572879791259766
# Redshift difference: -0.368621
#
# BCG index:  200
# Halo matched index: 9711
# Total angular separation:  1.83855310029
# RA difference:  0.028533935546875
# DEC difference:  -1.838334560394287
# Redshift difference: -0.215749
#
# BCG index:  205
# Halo matched index: 9488
# Total angular separation:  1.18432399339
# RA difference:  0.82080078125
# DEC difference:  -0.8583583831787109
# Redshift difference: -0.3323
#
# BCG index:  210
# Halo matched index: 12117
# Total angular separation:  0.372204250393
# RA difference:  -0.3137359619140625
# DEC difference:  -0.20262813568115234
# Redshift difference: -0.371958
#
# BCG index:  215
# Halo matched index: 732
# Total angular separation:  2.75476162056
# RA difference:  -0.824432373046875
# DEC difference:  -2.6303844451904297
# Redshift difference: -0.34463
#
# BCG index:  220
# Halo matched index: 10249
# Total angular separation:  0.387202222447
# RA difference:  0.3847198486328125
# DEC difference:  0.05474376678466797
# Redshift difference: -0.425179
#
# BCG index:  225
# Halo matched index: 732
# Total angular separation:  3.09856542999
# RA difference:  -0.8343658447265625
# DEC difference:  -2.9859066009521484
# Redshift difference: -0.343943
#
# BCG index:  230
# Halo matched index: 12280
# Total angular separation:  0.427419010397
# RA difference:  -0.2429351806640625
# DEC difference:  0.3520510196685791
# Redshift difference: -0.269178
#
# BCG index:  235
# Halo matched index: 9488
# Total angular separation:  2.99117845056
# RA difference:  -0.8448944091796875
# DEC difference:  -2.87135648727417
# Redshift difference: -0.302217
#
# BCG index:  240
# Halo matched index: 697
# Total angular separation:  0.0416819899304
# RA difference:  -0.0197906494140625
# DEC difference:  -0.036707401275634766
# Redshift difference: -0.387774
#
# BCG index:  245
# Halo matched index: 9877
# Total angular separation:  0.208073864953
# RA difference:  -0.0350799560546875
# DEC difference:  -0.20510244369506836
# Redshift difference: -0.24871
#
# BCG index:  250
# Halo matched index: 9488
# Total angular separation:  1.81063010414
# RA difference:  0.6202392578125
# DEC difference:  -1.7025947570800781
# Redshift difference: -0.306765
#
# BCG index:  255
# Halo matched index: 732
# Total angular separation:  3.62894291035
# RA difference:  0.130950927734375
# DEC difference:  -3.626619338989258
# Redshift difference: -0.368689
#
# BCG index:  260
# Halo matched index: 4475
# Total angular separation:  1.02467290433
# RA difference:  0.7539520263671875
# DEC difference:  -0.6965770721435547
# Redshift difference: -0.390057
#
# BCG index:  265
# Halo matched index: 9488
# Total angular separation:  2.33238179213
# RA difference:  -0.118804931640625
# DEC difference:  -2.3293986320495605
# Redshift difference: -0.327877
#
# BCG index:  270
# Halo matched index: 10249
# Total angular separation:  0.343338805118
# RA difference:  -0.261383056640625
# DEC difference:  0.22370147705078125
# Redshift difference: -0.445692
#
# BCG index:  275
# Halo matched index: 732
# Total angular separation:  1.07773412095
# RA difference:  -0.8437957763671875
# DEC difference:  -0.6760764122009277
# Redshift difference: -0.375079
#
# BCG index:  280
# Halo matched index: 9488
# Total angular separation:  2.27715133958
# RA difference:  -0.061767578125
# DEC difference:  -2.2763257026672363
# Redshift difference: -0.345844
#
# BCG index:  285
# Halo matched index: 5681
# Total angular separation:  0.305121373554
# RA difference:  -0.1856689453125
# DEC difference:  -0.2425394058227539
# Redshift difference: -0.320547
#
# BCG index:  290
# Halo matched index: 9260
# Total angular separation:  0.490165653223
# RA difference:  -0.149017333984375
# DEC difference:  -0.46718502044677734
# Redshift difference: -0.388592
#
# BCG index:  295
# Halo matched index: 12727
# Total angular separation:  0.28849076139
# RA difference:  0.2311553955078125
# DEC difference:  -0.1736927032470703
# Redshift difference: -0.289196
#
# BCG index:  300
# Halo matched index: 5290
# Total angular separation:  0.326739681233
# RA difference:  -0.1759490966796875
# DEC difference:  0.2756223678588867
# Redshift difference: -0.29342
#
# BCG index:  305
# Halo matched index: 697
# Total angular separation:  0.229791684641
# RA difference:  0.2200927734375
# DEC difference:  0.06759953498840332
# Redshift difference: -0.392365
#
# BCG index:  310
# Halo matched index: 9711
# Total angular separation:  0.520718160696
# RA difference:  0.20477294921875
# DEC difference:  -0.4792213439941406
# Redshift difference: -0.234285
#
# BCG index:  315
# Halo matched index: 3468
# Total angular separation:  0.270140348947
# RA difference:  0.23876953125
# DEC difference:  0.1271669864654541
# Redshift difference: -0.378125
#
# BCG index:  320
# Halo matched index: 732
# Total angular separation:  2.62667526631
# RA difference:  -0.1656494140625
# DEC difference:  -2.621522903442383
# Redshift difference: -0.331944
#
# BCG index:  325
# Halo matched index: 1828
# Total angular separation:  0.124086193709
# RA difference:  -0.1148223876953125
# DEC difference:  -0.04816865921020508
# Redshift difference: -0.350395
#
# BCG index:  330
# Halo matched index: 3142
# Total angular separation:  0.0642071687602
# RA difference:  0.0330047607421875
# DEC difference:  0.055141448974609375
# Redshift difference: -0.077496
#
# BCG index:  335
# Halo matched index: 732
# Total angular separation:  3.25934297807
# RA difference:  0.1048583984375
# DEC difference:  -3.2576828002929688
# Redshift difference: -0.36481
#
# BCG index:  340
# Halo matched index: 12368
# Total angular separation:  0.0173546281981
# RA difference:  -0.009033203125
# DEC difference:  0.014823198318481445
# Redshift difference: -0.133565
#
# BCG index:  345
# Halo matched index: 12368
# Total angular separation:  0.396988485733
# RA difference:  0.39398193359375
# DEC difference:  0.051436424255371094
# Redshift difference: -0.127307
#
# BCG index:  350
# Halo matched index: 2271
# Total angular separation:  0.595595262877
# RA difference:  0.5890045166015625
# DEC difference:  0.10418081283569336
# Redshift difference: -0.341027
#
# BCG index:  355
# Halo matched index: 2729
# Total angular separation:  1.0992813085
# RA difference:  -0.714630126953125
# DEC difference:  -0.8385310173034668
# Redshift difference: -0.153901
#
# BCG index:  360
# Halo matched index: 9482
# Total angular separation:  0.433706301814
# RA difference:  -0.427032470703125
# DEC difference:  -0.07841134071350098
# Redshift difference: -0.241079
#
# BCG index:  365
# Halo matched index: 5458
# Total angular separation:  0.258348364424
# RA difference:  -0.091888427734375
# DEC difference:  0.24152469635009766
# Redshift difference: -0.272324
#
# BCG index:  370
# Halo matched index: 6866
# Total angular separation:  0.354046398448
# RA difference:  0.1556549072265625
# DEC difference:  -0.31809210777282715
# Redshift difference: -0.39758
#
# BCG index:  375
# Halo matched index: 732
# Total angular separation:  1.83904659936
# RA difference:  -0.4820098876953125
# DEC difference:  -1.775589942932129
# Redshift difference: -0.356514
#
# BCG index:  380
# Halo matched index: 5413
# Total angular separation:  0.0795697584856
# RA difference:  -0.040863037109375
# DEC difference:  -0.06834030151367188
# Redshift difference: -0.43819
#
# BCG index:  385
# Halo matched index: 6866
# Total angular separation:  0.497429183023
# RA difference:  -0.4896087646484375
# DEC difference:  0.09083104133605957
# Redshift difference: -0.367082
#
# BCG index:  390
# Halo matched index: 1828
# Total angular separation:  0.15559738508
# RA difference:  -0.0029296875
# DEC difference:  -0.15557003021240234
# Redshift difference: -0.361292
#
# BCG index:  395
# Halo matched index: 13377
# Total angular separation:  0.610135320949
# RA difference:  0.4909515380859375
# DEC difference:  -0.36446571350097656
# Redshift difference: -0.392504
#
# BCG index:  400
# Halo matched index: 9711
# Total angular separation:  1.53412788097
# RA difference:  0.2407684326171875
# DEC difference:  -1.5153541564941406
# Redshift difference: -0.228324
#
# BCG index:  405
# Halo matched index: 9488
# Total angular separation:  1.0854337849
# RA difference:  -0.8607025146484375
# DEC difference:  -0.6676397323608398
# Redshift difference: -0.319101
#
# BCG index:  410
# Halo matched index: 9488
# Total angular separation:  0.766207614282
# RA difference:  0.51202392578125
# DEC difference:  -0.5725612640380859
# Redshift difference: -0.305442
#
# BCG index:  415
# Halo matched index: 9488
# Total angular separation:  0.616236462366
# RA difference:  0.3159332275390625
# DEC difference:  -0.5301299095153809
# Redshift difference: -0.326712
#
# BCG index:  420
# Halo matched index: 732
# Total angular separation:  2.41969412378
# RA difference:  -0.2625579833984375
# DEC difference:  -2.405608654022217
# Redshift difference: -0.361799
#
# BCG index:  425
# Halo matched index: 12117
# Total angular separation:  0.299948053247
# RA difference:  -0.287445068359375
# DEC difference:  -0.09015417098999023
# Redshift difference: -0.372683
#
# BCG index:  430
# Halo matched index: 9711
# Total angular separation:  1.70836999896
# RA difference:  0.1851806640625
# DEC difference:  -1.6984329223632812
# Redshift difference: -0.229888
#
# BCG index:  435
# Halo matched index: 732
# Total angular separation:  3.54934347214
# RA difference:  -0.5037078857421875
# DEC difference:  -3.514019012451172
# Redshift difference: -0.340834
#
# BCG index:  440
# Halo matched index: 9482
# Total angular separation:  0.563875752165
# RA difference:  -0.4918670654296875
# DEC difference:  -0.2767653465270996
# Redshift difference: -0.235309
#
# BCG index:  445
# Halo matched index: 3142
# Total angular separation:  0.299209921971
# RA difference:  -0.0608673095703125
# DEC difference:  -0.292999267578125
# Redshift difference: -0.0797878
#
# BCG index:  450
# Halo matched index: 11163
# Total angular separation:  0.293119648022
# RA difference:  0.1233673095703125
# DEC difference:  0.2661128044128418
# Redshift difference: -0.451665
#
# BCG index:  455
# Halo matched index: 9488
# Total angular separation:  1.34959939767
# RA difference:  0.8597869873046875
# DEC difference:  -1.044550895690918
# Redshift difference: -0.332575
#
# BCG index:  460
# Halo matched index: 9711
# Total angular separation:  1.15333817301
# RA difference:  0.31549072265625
# DEC difference:  -1.1098694801330566
# Redshift difference: -0.223362
#
# BCG index:  465
# Halo matched index: 9260
# Total angular separation:  0.542414279162
# RA difference:  -0.5447235107421875
# DEC difference:  0.0027523040771484375
# Redshift difference: -0.391841
#
# BCG index:  470
# Halo matched index: 732
# Total angular separation:  2.89352347783
# RA difference:  -0.020538330078125
# DEC difference:  -2.893451690673828
# Redshift difference: -0.328031
#
# BCG index:  475
# Halo matched index: 9488
# Total angular separation:  0.267565936877
# RA difference:  0.1632080078125
# DEC difference:  -0.21268272399902344
# Redshift difference: -0.304037
#
# BCG index:  480
# Halo matched index: 13016
# Total angular separation:  0.148186146299
# RA difference:  -0.1292572021484375
# DEC difference:  -0.07341670989990234
# Redshift difference: -0.398258
#
# BCG index:  485
# Halo matched index: 732
# Total angular separation:  2.51039435984
# RA difference:  -0.358673095703125
# DEC difference:  -2.4850082397460938
# Redshift difference: -0.331734
#
# BCG index:  490
# Halo matched index: 5235
# Total angular separation:  0.158339013627
# RA difference:  0.0392303466796875
# DEC difference:  0.1534125804901123
# Redshift difference: -0.382752
#
# BCG index:  495
# Halo matched index: 6750
# Total angular separation:  0.282720160507
# RA difference:  -0.275238037109375
# DEC difference:  0.06716585159301758
# Redshift difference: -0.383362
#
# BCG index:  500
# Halo matched index: 6971
# Total angular separation:  0.126008296971
# RA difference:  0.1050567626953125
# DEC difference:  -0.06987571716308594
# Redshift difference: -0.070494
#
# BCG index:  505
# Halo matched index: 9488
# Total angular separation:  2.04213956522
# RA difference:  0.368438720703125
# DEC difference:  -2.0091018676757812
# Redshift difference: -0.307698
#
# BCG index:  510
# Halo matched index: 5458
# Total angular separation:  0.099099347181
# RA difference:  -0.02911376953125
# DEC difference:  -0.09474587440490723
# Redshift difference: -0.272344
#
# BCG index:  515
# Halo matched index: 7122
# Total angular separation:  0.405116374907
# RA difference:  0.22979736328125
# DEC difference:  -0.33408451080322266
# Redshift difference: -0.359108
#
# BCG index:  520
# Halo matched index: 7704
# Total angular separation:  0.185992197859
# RA difference:  0.020233154296875
# DEC difference:  -0.18489885330200195
# Redshift difference: -0.293372
#
# BCG index:  525
# Halo matched index: 9260
# Total angular separation:  0.780321127445
# RA difference:  -0.78253173828125
# DEC difference:  0.04127979278564453
# Redshift difference: -0.391738
#
# BCG index:  530
# Halo matched index: 3468
# Total angular separation:  0.284431491125
# RA difference:  0.1074371337890625
# DEC difference:  -0.26344871520996094
# Redshift difference: -0.387267
#
# BCG index:  535
# Halo matched index: 2729
# Total angular separation:  0.632349435232
# RA difference:  -0.5522613525390625
# DEC difference:  -0.3127617835998535
# Redshift difference: -0.154461
#
# BCG index:  540
# Halo matched index: 2729
# Total angular separation:  0.875533724799
# RA difference:  -0.7563018798828125
# DEC difference:  -0.4474673271179199
# Redshift difference: -0.154363
#
# BCG index:  545
# Halo matched index: 13475
# Total angular separation:  0.434007093145
# RA difference:  0.2866973876953125
# DEC difference:  -0.32658863067626953
# Redshift difference: -0.372518
#
# BCG index:  550
# Halo matched index: 9711
# Total angular separation:  0.331754084518
# RA difference:  -0.048065185546875
# DEC difference:  -0.3282895088195801
# Redshift difference: -0.236073
#
# BCG index:  555
# Halo matched index: 3932
# Total angular separation:  0.218232483406
# RA difference:  -0.218017578125
# DEC difference:  0.019479751586914062
# Redshift difference: -0.229419
#
# BCG index:  560
# Halo matched index: 2729
# Total angular separation:  0.427024480218
# RA difference:  0.3460845947265625
# DEC difference:  -0.2524285316467285
# Redshift difference: -0.16644
#
# BCG index:  565
# Halo matched index: 9711
# Total angular separation:  2.2334430013
# RA difference:  0.73291015625
# DEC difference:  -2.1115012168884277
# Redshift difference: -0.241846
#
# BCG index:  570
# Halo matched index: 12280
# Total angular separation:  0.478929235383
# RA difference:  0.405487060546875
# DEC difference:  -0.25657176971435547
# Redshift difference: -0.270054
#
# BCG index:  575
# Halo matched index: 732
# Total angular separation:  3.05439950788
# RA difference:  -0.254241943359375
# DEC difference:  -3.043964385986328
# Redshift difference: -0.363254
#
# BCG index:  580
# Halo matched index: 9711
# Total angular separation:  0.836545696174
# RA difference:  0.5341949462890625
# DEC difference:  -0.6461496353149414
# Redshift difference: -0.244008
#
# BCG index:  585
# Halo matched index: 9488
# Total angular separation:  0.332455942202
# RA difference:  0.0568389892578125
# DEC difference:  -0.32761383056640625
# Redshift difference: -0.314222
#
# BCG index:  590
# Halo matched index: 5302
# Total angular separation:  0.194180413651
# RA difference:  -0.02105712890625
# DEC difference:  -0.19304561614990234
# Redshift difference: -0.0147534
#
# BCG index:  595
# Halo matched index: 12368
# Total angular separation:  0.598985263534
# RA difference:  0.3205413818359375
# DEC difference:  0.5061444044113159
# Redshift difference: -0.121567
#
# BCG index:  600
# Halo matched index: 10490
# Total angular separation:  0.457292846306
# RA difference:  0.4382171630859375
# DEC difference:  0.13310027122497559
# Redshift difference: -0.407344
#
# BCG index:  605
# Halo matched index: 9711
# Total angular separation:  0.879787383369
# RA difference:  0.380859375
# DEC difference:  -0.7940840721130371
# Redshift difference: -0.227723
#
# BCG index:  610
# Halo matched index: 9711
# Total angular separation:  2.30379918176
# RA difference:  0.53192138671875
# DEC difference:  -2.242429256439209
# Redshift difference: -0.237148
#
# BCG index:  615
# Halo matched index: 732
# Total angular separation:  2.95791078223
# RA difference:  0.420562744140625
# DEC difference:  -2.9283199310302734
# Redshift difference: -0.353648
#
# BCG index:  620
# Halo matched index: 732
# Total angular separation:  0.491102988009
# RA difference:  -0.380126953125
# DEC difference:  -0.3132510185241699
# Redshift difference: -0.351191
#
# BCG index:  625
# Halo matched index: 9711
# Total angular separation:  1.45248500847
# RA difference:  0.9391632080078125
# DEC difference:  -1.112623691558838
# Redshift difference: -0.25002
#
# BCG index:  630
# Halo matched index: 732
# Total angular separation:  2.35212706393
# RA difference:  -0.83099365234375
# DEC difference:  -2.2025818824768066
# Redshift difference: -0.371566
#
# BCG index:  635
# Halo matched index: 9711
# Total angular separation:  1.19445686342
# RA difference:  -0.19439697265625
# DEC difference:  -1.1787199974060059
# Redshift difference: -0.222468
#
# BCG index:  640
# Halo matched index: 8777
# Total angular separation:  0.186466070148
# RA difference:  -0.1718902587890625
# DEC difference:  -0.07277774810791016
# Redshift difference: -0.150291
#
# BCG index:  645
# Halo matched index: 11163
# Total angular separation:  0.42597116773
# RA difference:  0.3278045654296875
# DEC difference:  -0.2736930847167969
# Redshift difference: -0.424417
#
# BCG index:  650
# Halo matched index: 732
# Total angular separation:  2.67621745295
# RA difference:  -0.3032989501953125
# DEC difference:  -2.6592283248901367
# Redshift difference: -0.338747
#
# BCG index:  655
# Halo matched index: 9488
# Total angular separation:  0.973227027947
# RA difference:  0.5133056640625
# DEC difference:  -0.8287043571472168
# Redshift difference: -0.331831
#
# BCG index:  660
# Halo matched index: 5290
# Total angular separation:  0.437367853307
# RA difference:  -0.43463134765625
# DEC difference:  -0.0590510368347168
# Redshift difference: -0.285178
#
# BCG index:  665
# Halo matched index: 6750
# Total angular separation:  0.197676112779
# RA difference:  -0.125518798828125
# DEC difference:  -0.1529541015625
# Redshift difference: -0.377129
#
# BCG index:  670
# Halo matched index: 9002
# Total angular separation:  0.96901094761
# RA difference:  -0.0562591552734375
# DEC difference:  -0.9673855304718018
# Redshift difference: -0.354392
#
# BCG index:  675
# Halo matched index: 9260
# Total angular separation:  0.790515412625
# RA difference:  -0.4544525146484375
# DEC difference:  -0.6483550071716309
# Redshift difference: -0.399311
#
# BCG index:  680
# Halo matched index: 2729
# Total angular separation:  0.716571405158
# RA difference:  -0.206512451171875
# DEC difference:  -0.6864891052246094
# Redshift difference: -0.180903
#
# BCG index:  685
# Halo matched index: 12117
# Total angular separation:  0.461195870039
# RA difference:  -0.19818115234375
# DEC difference:  0.4168519973754883
# Redshift difference: -0.367081
#
# BCG index:  690
# Halo matched index: 2729
# Total angular separation:  0.0810365332935
# RA difference:  0.0795745849609375
# DEC difference:  -0.017111778259277344
# Redshift difference: -0.181235
#
# BCG index:  695
# Halo matched index: 9711
# Total angular separation:  0.976009781214
# RA difference:  -0.697235107421875
# DEC difference:  -0.6868157386779785
# Redshift difference: -0.244531
#
# BCG index:  700
# Halo matched index: 732
# Total angular separation:  2.24335478617
# RA difference:  -0.0323333740234375
# DEC difference:  -2.2431249618530273
# Redshift difference: -0.339273
#
# BCG index:  705
# Halo matched index: 3468
# Total angular separation:  0.416122532094
# RA difference:  0.416656494140625
# DEC difference:  0.014312505722045898
# Redshift difference: -0.395478
#
# BCG index:  710
# Halo matched index: 9711
# Total angular separation:  2.52832238369
# RA difference:  0.43853759765625
# DEC difference:  -2.49055814743042
# Redshift difference: -0.238829
#
# BCG index:  715
# Halo matched index: 7508
# Total angular separation:  1.6163950335
# RA difference:  1.070220947265625
# DEC difference:  1.2114726901054382
# Redshift difference: -0.322511
#
# BCG index:  720
# Halo matched index: 13475
# Total angular separation:  0.445735178189
# RA difference:  0.354583740234375
# DEC difference:  -0.2714691162109375
# Redshift difference: -0.358688
#
# BCG index:  725
# Halo matched index: 7122
# Total angular separation:  0.377030035484
# RA difference:  0.263580322265625
# DEC difference:  -0.2703070640563965
# Redshift difference: -0.38103
#
# BCG index:  730
# Halo matched index: 732
# Total angular separation:  3.4360417616
# RA difference:  -0.174041748046875
# DEC difference:  -3.431703567504883
# Redshift difference: -0.344641
#
# BCG index:  735
# Halo matched index: 10454
# Total angular separation:  0.284194021112
# RA difference:  0.0776214599609375
# DEC difference:  0.2734527587890625
# Redshift difference: -0.349624
#
# BCG index:  740
# Halo matched index: 11163
# Total angular separation:  0.143288687359
# RA difference:  0.0941009521484375
# DEC difference:  -0.10839509963989258
# Redshift difference: -0.452152
#
# BCG index:  745
# Halo matched index: 732
# Total angular separation:  1.83481909565
# RA difference:  -0.432342529296875
# DEC difference:  -1.7838234901428223
# Redshift difference: -0.35398
#
# BCG index:  750
# Halo matched index: 2729
# Total angular separation:  1.24524895859
# RA difference:  -0.4364471435546875
# DEC difference:  -1.1671733856201172
# Redshift difference: -0.16098
#
# BCG index:  755
# Halo matched index: 11163
# Total angular separation:  0.430567283887
# RA difference:  0.137115478515625
# DEC difference:  -0.4083518981933594
# Redshift difference: -0.451698
#
# BCG index:  760
# Halo matched index: 5235
# Total angular separation:  0.686204083822
# RA difference:  -0.5754547119140625
# DEC difference:  0.3746461868286133
# Redshift difference: -0.348628
#
# BCG index:  765
# Halo matched index: 6971
# Total angular separation:  0.392951750862
# RA difference:  -0.2796173095703125
# DEC difference:  -0.27665233612060547
# Redshift difference: -0.0758522
#
# BCG index:  770
# Halo matched index: 12392
# Total angular separation:  0.244983830654
# RA difference:  -0.055572509765625
# DEC difference:  -0.23861908912658691
# Redshift difference: -0.409787
#
# BCG index:  775
# Halo matched index: 1713
# Total angular separation:  0.481410951165
# RA difference:  -0.48211669921875
# DEC difference:  -0.00040078163146972656
# Redshift difference: -0.321279
#
# BCG index:  780
# Halo matched index: 12368
# Total angular separation:  0.705136400575
# RA difference:  -0.5687713623046875
# DEC difference:  0.41736459732055664
# Redshift difference: -0.122806
#
# BCG index:  785
# Halo matched index: 5681
# Total angular separation:  0.297010259167
# RA difference:  -0.1795806884765625
# DEC difference:  -0.23696422576904297
# Redshift difference: -0.299117
#
# BCG index:  790
# Halo matched index: 12890
# Total angular separation:  0.401445093053
# RA difference:  -0.396636962890625
# DEC difference:  0.06640362739562988
# Redshift difference: -0.162895
#
# BCG index:  795
# Halo matched index: 10121
# Total angular separation:  0.216808591173
# RA difference:  -0.13470458984375
# DEC difference:  -0.17011165618896484
# Redshift difference: -0.221642
#
# BCG index:  800
# Halo matched index: 7508
# Total angular separation:  1.54536690931
# RA difference:  0.7707366943359375
# DEC difference:  1.3395029306411743
# Redshift difference: -0.341118
#
# BCG index:  805
# Halo matched index: 7495
# Total angular separation:  0.225258721845
# RA difference:  -0.224578857421875
# DEC difference:  0.022979021072387695
# Redshift difference: -0.471027
#
# BCG index:  810
# Halo matched index: 12117
# Total angular separation:  0.331362959961
# RA difference:  -0.133392333984375
# DEC difference:  0.3035869598388672
# Redshift difference: -0.37074
#
# BCG index:  815
# Halo matched index: 7122
# Total angular separation:  0.110471606669
# RA difference:  0.026947021484375
# DEC difference:  0.10715198516845703
# Redshift difference: -0.403208
#
# BCG index:  820
# Halo matched index: 7508
# Total angular separation:  1.18069101454
# RA difference:  1.1588134765625
# DEC difference:  0.22790682315826416
# Redshift difference: -0.383249
#
# BCG index:  825
# Halo matched index: 697
# Total angular separation:  0.191507936233
# RA difference:  0.0185394287109375
# DEC difference:  -0.1906125545501709
# Redshift difference: -0.477219
#
# BCG index:  830
# Halo matched index: 9711
# Total angular separation:  0.450925764137
# RA difference:  -0.3921356201171875
# DEC difference:  -0.22605228424072266
# Redshift difference: -0.291652
#
# BCG index:  835
# Halo matched index: 982
# Total angular separation:  0.301554530251
# RA difference:  -0.176727294921875
# DEC difference:  0.2448420524597168
# Redshift difference: -0.385633
#
# BCG index:  840
# Halo matched index: 9260
# Total angular separation:  1.40358804729
# RA difference:  -1.3506622314453125
# DEC difference:  -0.4030733108520508
# Redshift difference: -0.478093
#
# BCG index:  845
# Halo matched index: 13016
# Total angular separation:  0.140981084715
# RA difference:  -0.1196136474609375
# DEC difference:  -0.07541036605834961
# Redshift difference: -0.48225
#
# BCG index:  850
# Halo matched index: 10834
# Total angular separation:  0.20371185455
# RA difference:  0.180938720703125
# DEC difference:  -0.09446048736572266
# Redshift difference: -0.490783
#
# BCG index:  855
# Halo matched index: 6971
# Total angular separation:  0.342267092999
# RA difference:  0.330413818359375
# DEC difference:  -0.09157514572143555
# Redshift difference: -0.111232
#
# BCG index:  860
# Halo matched index: 5302
# Total angular separation:  0.223480749882
# RA difference:  0.2227783203125
# DEC difference:  -0.027302265167236328
# Redshift difference: -0.175546
#
# BCG index:  865
# Halo matched index: 10454
# Total angular separation:  0.401508009786
# RA difference:  0.2257080078125
# DEC difference:  0.3325037956237793
# Redshift difference: -0.449923
#
# BCG index:  870
# Halo matched index: 9488
# Total angular separation:  1.11950313528
# RA difference:  0.09063720703125
# DEC difference:  -1.115872859954834
# Redshift difference: -0.355747
#
# BCG index:  875
# Halo matched index: 11609
# Total angular separation:  0.390392086363
# RA difference:  0.385223388671875
# DEC difference:  0.06835484504699707
# Redshift difference: -0.436008
#
# BCG index:  880
# Halo matched index: 2729
# Total angular separation:  0.41654476912
# RA difference:  0.2049102783203125
# DEC difference:  -0.363222599029541
# Redshift difference: -0.232574
#
# BCG index:  885
# Halo matched index: 12117
# Total angular separation:  0.597033574289
# RA difference:  -0.1237640380859375
# DEC difference:  0.584174633026123
# Redshift difference: -0.507268
#
# BCG index:  890
# Halo matched index: 3468
# Total angular separation:  0.194266271487
# RA difference:  0.04730224609375
# DEC difference:  0.18844056129455566
# Redshift difference: -0.472982
#
# BCG index:  895
# Halo matched index: 9488
# Total angular separation:  0.416318678794
# RA difference:  0.327301025390625
# DEC difference:  -0.2594752311706543
# Redshift difference: -0.355709
#
# BCG index:  900
# Halo matched index: 5458
# Total angular separation:  0.537925298466
# RA difference:  0.397491455078125
# DEC difference:  -0.36346435546875
# Redshift difference: -0.372738
#
# BCG index:  905
# Halo matched index: 537
# Total angular separation:  0.334951103619
# RA difference:  -0.09893798828125
# DEC difference:  0.3200397491455078
# Redshift difference: -0.420744
#
# BCG index:  910
# Halo matched index: 13475
# Total angular separation:  0.265861772091
# RA difference:  0.0905914306640625
# DEC difference:  -0.2500481605529785
# Redshift difference: -0.443126
#
# BCG index:  915
# Halo matched index: 7313
# Total angular separation:  0.248557417794
# RA difference:  0.0225372314453125
# DEC difference:  -0.24753880500793457
# Redshift difference: -0.558949
#
# BCG index:  920
# Halo matched index: 9002
# Total angular separation:  0.268067017951
# RA difference:  0.0395355224609375
# DEC difference:  -0.2651493549346924
# Redshift difference: -0.43943
#
# BCG index:  925
# Halo matched index: 6866
# Total angular separation:  0.427491158287
# RA difference:  -0.4065704345703125
# DEC difference:  -0.1335911750793457
# Redshift difference: -0.463409
#
# BCG index:  930
# Halo matched index: 2729
# Total angular separation:  0.964683895312
# RA difference:  -0.7391510009765625
# DEC difference:  -0.6243782043457031
# Redshift difference: -0.28466
#
# BCG index:  935
# Halo matched index: 7313
# Total angular separation:  0.271604287937
# RA difference:  -0.2482452392578125
# DEC difference:  0.1114954948425293
# Redshift difference: -0.468428
#
# BCG index:  940
# Halo matched index: 1828
# Total angular separation:  0.909213939412
# RA difference:  -0.099365234375
# DEC difference:  -0.9038200378417969
# Redshift difference: -0.388895
#
# BCG index:  945
# Halo matched index: 2729
# Total angular separation:  0.70559295397
# RA difference:  -0.4913787841796875
# DEC difference:  -0.5087471008300781
# Redshift difference: -0.206097
#
# BCG index:  950
# Halo matched index: 9488
# Total angular separation:  2.73563493898
# RA difference:  -0.381988525390625
# DEC difference:  -2.7092537879943848
# Redshift difference: -0.35589
#
# BCG index:  955
# Halo matched index: 12117
# Total angular separation:  0.665612254039
# RA difference:  -0.2989654541015625
# DEC difference:  0.5953211784362793
# Redshift difference: -0.409819
#
# BCG index:  960
# Halo matched index: 9711
# Total angular separation:  2.16957566175
# RA difference:  0.828338623046875
# DEC difference:  -2.007516384124756
# Redshift difference: -0.341009
#
# BCG index:  965
# Halo matched index: 13048
# Total angular separation:  0.227280518488
# RA difference:  -0.024169921875
# DEC difference:  -0.22599387168884277
# Redshift difference: -0.390333
#
# BCG index:  970
# Halo matched index: 8476
# Total angular separation:  0.578149709961
# RA difference:  -0.5748138427734375
# DEC difference:  0.0717628002166748
# Redshift difference: -0.493857
#
# BCG index:  975
# Halo matched index: 9260
# Total angular separation:  0.724159697109
# RA difference:  -0.5294952392578125
# DEC difference:  -0.4966411590576172
# Redshift difference: -0.461893
#
# BCG index:  980
# Halo matched index: 9002
# Total angular separation:  0.283809912331
# RA difference:  0.062408447265625
# DEC difference:  -0.27689623832702637
# Redshift difference: -0.450783
#
# BCG index:  985
# Halo matched index: 13061
# Total angular separation:  0.224402390801
# RA difference:  0.0188446044921875
# DEC difference:  0.22361135482788086
# Redshift difference: -0.45065
#
# BCG index:  990
# Halo matched index: 6866
# Total angular separation:  0.374140720597
# RA difference:  0.234527587890625
# DEC difference:  0.2917039394378662
# Redshift difference: -0.484268
#
# BCG index:  995
# Halo matched index: 13475
# Total angular separation:  1.16462201624
# RA difference:  -0.739166259765625
# DEC difference:  -0.9020557403564453
# Redshift difference: -0.435808

# %% [markdown]
# ## Try to match
